# %%
# general
import pandas as pd
import numpy as np
import sys
import random

# spotipy dependencies
import spotipy
import spotipy.oauth2
from spotipy.oauth2 import SpotifyOAuth
import spotipy.util as util

# ML dependencies
import statsmodels.api as sm
import joblib
from joblib import load
from sklearn.neighbors import NearestNeighbors
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import IsolationForest

# %%
# lets us see all queried data
pd.set_option('display.max_rows', None)

# globals
client_id = '84bb0f8b3cfa4cc69a8c5175ae89c6b5'
client_secret = 'a01aa1e389bd45f9a83ceb76b89f5aee'
redirect_uri = 'http://localhost:8888/callback'
scope = 'user-top-read user-library-read playlist-modify-private playlist-modify-public'

# oauth2 login
sp_oauth = SpotifyOAuth(client_id = client_id,
                        client_secret = client_secret,
                        redirect_uri = redirect_uri,
                        scope = scope)
token_info = sp_oauth.get_cached_token() 
token = token_info['access_token']
sp = spotipy.Spotify(auth = token)

# new login
if not token_info:
    auth_url = sp_oauth.get_authorize_url()
    print(auth_url)
    response = input('Paste the redirect url here: ')
    code = sp_oauth.parse_response_code(response)
    token_info = sp_oauth.get_access_token(code)
    token = token_info['access_token']
sp = spotipy.Spotify(auth=token)

# your user id
user_id = sp.current_user()['display_name']

# function to refresh access token
def refresh():
    global token_info, sp
    if sp_oauth.is_token_expired(token_info):
        token_info = sp_oauth.refresh_access_token(token_info['refresh_token'])
        token = token_info['access_token']
        sp = spotipy.Spotify(auth=token)

# function to easily rank data        
def rank(data):
    refresh()
    ranked = data.sort_values(by = ['scores'], ascending = False)
    return ranked[['scores', 'name', 'artist', 'album', 'track_id']]

# %%
# id for the playlist you'd like to work with
playlist_id = '6vqdAph2gxHHgvojxM7js4'

# %%
# returns metadata for each song in the playlist
results = sp.user_playlist_tracks(user_id, playlist_id)
tracks = results['items']
while results['next']:
    results = sp.next(results)
    tracks.extend(results['items'])
tracks[:5]
# Out:
# [{'added_at': '2020-11-22T19:27:19Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/cloud_none'},
#    'href': 'https://api.spotify.com/v1/users/cloud_none',
#    'id': 'cloud_none',
#    'type': 'user',
#    'uri': 'spotify:user:cloud_none'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5EHvXKnNz78jkAVgTQLQ5O'},
#       'href': 'https://api.spotify.com/v1/artists/5EHvXKnNz78jkAVgTQLQ5O',
#       'id': '5EHvXKnNz78jkAVgTQLQ5O',
#       'name': 'Dark Tranquillity',
#       'type': 'artist',
#       'uri': 'spotify:artist:5EHvXKnNz78jkAVgTQLQ5O'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7cLSmdYZAdbDYsuPlHWVIG'},
#     'href': 'https://api.spotify.com/v1/albums/7cLSmdYZAdbDYsuPlHWVIG',
#     'id': '7cLSmdYZAdbDYsuPlHWVIG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738c4ba9a351ba5e5b6271e941',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028c4ba9a351ba5e5b6271e941',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518c4ba9a351ba5e5b6271e941',
#       'width': 64}],
#     'name': 'Fiction',
#     'release_date': '2007-09-26',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:7cLSmdYZAdbDYsuPlHWVIG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5EHvXKnNz78jkAVgTQLQ5O'},
#      'href': 'https://api.spotify.com/v1/artists/5EHvXKnNz78jkAVgTQLQ5O',
#      'id': '5EHvXKnNz78jkAVgTQLQ5O',
#      'name': 'Dark Tranquillity',
#      'type': 'artist',
#      'uri': 'spotify:artist:5EHvXKnNz78jkAVgTQLQ5O'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 277826,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'US4E40731502'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7LkxDAm3CxOMSFDZcRx0kI'},
#    'href': 'https://api.spotify.com/v1/tracks/7LkxDAm3CxOMSFDZcRx0kI',
#    'id': '7LkxDAm3CxOMSFDZcRx0kI',
#    'is_local': False,
#    'name': 'The Lesser Faith',
#    'popularity': 35,
#    'preview_url': 'https://p.scdn.co/mp3-preview/edae65b817cd5a3b2cdcf9fe5cae17fb067c41a3?cid=84bb0f8b3cfa4cc69a8c5175ae89c6b5',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:7LkxDAm3CxOMSFDZcRx0kI'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-22T19:27:41Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/cloud_none'},
#    'href': 'https://api.spotify.com/v1/users/cloud_none',
#    'id': 'cloud_none',
#    'type': 'user',
#    'uri': 'spotify:user:cloud_none'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1xUhNgw4eJDZfvumIpcz1B'},
#       'href': 'https://api.spotify.com/v1/artists/1xUhNgw4eJDZfvumIpcz1B',
#       'id': '1xUhNgw4eJDZfvumIpcz1B',
#       'name': 'Children Of Bodom',
#       'type': 'artist',
#       'uri': 'spotify:artist:1xUhNgw4eJDZfvumIpcz1B'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5MCc07PcloHExkLxifoILv'},
#     'href': 'https://api.spotify.com/v1/albums/5MCc07PcloHExkLxifoILv',
#     'id': '5MCc07PcloHExkLxifoILv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273679b19fc87ece9ae886789cf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02679b19fc87ece9ae886789cf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851679b19fc87ece9ae886789cf',
#       'width': 64}],
#     'name': 'Hatebreeder',
#     'release_date': '1999-05-04',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:5MCc07PcloHExkLxifoILv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1xUhNgw4eJDZfvumIpcz1B'},
#      'href': 'https://api.spotify.com/v1/artists/1xUhNgw4eJDZfvumIpcz1B',
#      'id': '1xUhNgw4eJDZfvumIpcz1B',
#      'name': 'Children Of Bodom',
#      'type': 'artist',
#      'uri': 'spotify:artist:1xUhNgw4eJDZfvumIpcz1B'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 259173,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'FISFS9800107'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/23pLHGVFWELvxIiw0CQMaX'},
#    'href': 'https://api.spotify.com/v1/tracks/23pLHGVFWELvxIiw0CQMaX',
#    'id': '23pLHGVFWELvxIiw0CQMaX',
#    'is_local': False,
#    'name': 'Hatebreeder',
#    'popularity': 44,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c47b58c4a4dda82bdebb52b6358f01c077cba750?cid=84bb0f8b3cfa4cc69a8c5175ae89c6b5',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:23pLHGVFWELvxIiw0CQMaX'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-22T19:27:41Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/cloud_none'},
#    'href': 'https://api.spotify.com/v1/users/cloud_none',
#    'id': 'cloud_none',
#    'type': 'user',
#    'uri': 'spotify:user:cloud_none'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1xUhNgw4eJDZfvumIpcz1B'},
#       'href': 'https://api.spotify.com/v1/artists/1xUhNgw4eJDZfvumIpcz1B',
#       'id': '1xUhNgw4eJDZfvumIpcz1B',
#       'name': 'Children Of Bodom',
#       'type': 'artist',
#       'uri': 'spotify:artist:1xUhNgw4eJDZfvumIpcz1B'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5MCc07PcloHExkLxifoILv'},
#     'href': 'https://api.spotify.com/v1/albums/5MCc07PcloHExkLxifoILv',
#     'id': '5MCc07PcloHExkLxifoILv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273679b19fc87ece9ae886789cf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02679b19fc87ece9ae886789cf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851679b19fc87ece9ae886789cf',
#       'width': 64}],
#     'name': 'Hatebreeder',
#     'release_date': '1999-05-04',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:5MCc07PcloHExkLxifoILv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1xUhNgw4eJDZfvumIpcz1B'},
#      'href': 'https://api.spotify.com/v1/artists/1xUhNgw4eJDZfvumIpcz1B',
#      'id': '1xUhNgw4eJDZfvumIpcz1B',
#      'name': 'Children Of Bodom',
#      'type': 'artist',
#      'uri': 'spotify:artist:1xUhNgw4eJDZfvumIpcz1B'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 294066,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'FIUM70800199'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2dzCUvvliKLw9dj84IRlAg'},
#    'href': 'https://api.spotify.com/v1/tracks/2dzCUvvliKLw9dj84IRlAg',
#    'id': '2dzCUvvliKLw9dj84IRlAg',
#    'is_local': False,
#    'name': 'Towards Dead End',
#    'popularity': 39,
#    'preview_url': 'https://p.scdn.co/mp3-preview/72d5e1870de85bffadf47d5f31af1a1e4c348566?cid=84bb0f8b3cfa4cc69a8c5175ae89c6b5',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:2dzCUvvliKLw9dj84IRlAg'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-22T19:28:04Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/cloud_none'},
#    'href': 'https://api.spotify.com/v1/users/cloud_none',
#    'id': 'cloud_none',
#    'type': 'user',
#    'uri': 'spotify:user:cloud_none'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4EvbQBS99RXzFGGimAS3i9'},
#       'href': 'https://api.spotify.com/v1/artists/4EvbQBS99RXzFGGimAS3i9',
#       'id': '4EvbQBS99RXzFGGimAS3i9',
#       'name': 'Blood Stain Child',
#       'type': 'artist',
#       'uri': 'spotify:artist:4EvbQBS99RXzFGGimAS3i9'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4TQyTokknRMto3WhTdodZK'},
#     'href': 'https://api.spotify.com/v1/albums/4TQyTokknRMto3WhTdodZK',
#     'id': '4TQyTokknRMto3WhTdodZK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d396dcff123c425a196ac2f1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d396dcff123c425a196ac2f1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d396dcff123c425a196ac2f1',
#       'width': 64}],
#     'name': 'Epsilon',
#     'release_date': '2011-06-30',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:4TQyTokknRMto3WhTdodZK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4EvbQBS99RXzFGGimAS3i9'},
#      'href': 'https://api.spotify.com/v1/artists/4EvbQBS99RXzFGGimAS3i9',
#      'id': '4EvbQBS99RXzFGGimAS3i9',
#      'name': 'Blood Stain Child',
#      'type': 'artist',
#      'uri': 'spotify:artist:4EvbQBS99RXzFGGimAS3i9'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 269880,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'ITY101114007'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4ueVppRcLrdLdL7sQTHhWb'},
#    'href': 'https://api.spotify.com/v1/tracks/4ueVppRcLrdLdL7sQTHhWb',
#    'id': '4ueVppRcLrdLdL7sQTHhWb',
#    'is_local': False,
#    'name': 'Eternal',
#    'popularity': 27,
#    'preview_url': 'https://p.scdn.co/mp3-preview/28e654a1a2499868c3a9f37beffdc02042a5466e?cid=84bb0f8b3cfa4cc69a8c5175ae89c6b5',
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:4ueVppRcLrdLdL7sQTHhWb'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2020-11-22T19:28:48Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/cloud_none'},
#    'href': 'https://api.spotify.com/v1/users/cloud_none',
#    'id': 'cloud_none',
#    'type': 'user',
#    'uri': 'spotify:user:cloud_none'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2UOVgpgiNTC6KK0vSC77aD'},
#       'href': 'https://api.spotify.com/v1/artists/2UOVgpgiNTC6KK0vSC77aD',
#       'id': '2UOVgpgiNTC6KK0vSC77aD',
#       'name': 'Amorphis',
#       'type': 'artist',
#       'uri': 'spotify:artist:2UOVgpgiNTC6KK0vSC77aD'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7MGWDPW6Sqy0Lc0fUYFGeo'},
#     'href': 'https://api.spotify.com/v1/albums/7MGWDPW6Sqy0Lc0fUYFGeo',
#     'id': '7MGWDPW6Sqy0Lc0fUYFGeo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273026a2b2cb4e98b66048640e5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02026a2b2cb4e98b66048640e5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851026a2b2cb4e98b66048640e5',
#       'width': 64}],
#     'name': 'Skyforger',
#     'release_date': '2009-05-29',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:7MGWDPW6Sqy0Lc0fUYFGeo'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2UOVgpgiNTC6KK0vSC77aD'},
#      'href': 'https://api.spotify.com/v1/artists/2UOVgpgiNTC6KK0vSC77aD',
#      'id': '2UOVgpgiNTC6KK0vSC77aD',
#      'name': 'Amorphis',
#      'type': 'artist',
#      'uri': 'spotify:artist:2UOVgpgiNTC6KK0vSC77aD'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 368840,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DED830900114'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4Lgj2JWNhM5DTWAMhz34AS'},
#    'href': 'https://api.spotify.com/v1/tracks/4Lgj2JWNhM5DTWAMhz34AS',
#    'id': '4Lgj2JWNhM5DTWAMhz34AS',
#    'is_local': False,
#    'name': 'Sampo',
#    'popularity': 16,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4Lgj2JWNhM5DTWAMhz34AS'},
#   'video_thumbnail': {'url': None}}]

# %%
# returns ids for each track in the playlist 
track_list = []
for i in range(len(tracks)):
    ids = tracks[i]['track']['id']
    track_list.append(ids)
track_list[:5]
# Out:
# ['7LkxDAm3CxOMSFDZcRx0kI',
#  '23pLHGVFWELvxIiw0CQMaX',
#  '2dzCUvvliKLw9dj84IRlAg',
#  '4ueVppRcLrdLdL7sQTHhWb',
#  '4Lgj2JWNhM5DTWAMhz34AS']

# %%
# returns audio featurs for the first track
sp.audio_features(track_list[0])
# Out:
# [{'danceability': 0.411,
#   'energy': 0.965,
#   'key': 7,
#   'loudness': -4.503,
#   'mode': 1,
#   'speechiness': 0.0565,
#   'acousticness': 2.51e-05,
#   'instrumentalness': 0.216,
#   'liveness': 0.063,
#   'valence': 0.422,
#   'tempo': 159.993,
#   'type': 'audio_features',
#   'id': '7LkxDAm3CxOMSFDZcRx0kI',
#   'uri': 'spotify:track:7LkxDAm3CxOMSFDZcRx0kI',
#   'track_href': 'https://api.spotify.com/v1/tracks/7LkxDAm3CxOMSFDZcRx0kI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7LkxDAm3CxOMSFDZcRx0kI',
#   'duration_ms': 277827,
#   'time_signature': 4}]

# %%
# returns our all the descriptive data for tracks in our playlist

refresh()

def getTrackFeatures(track_id):
    t_id = track_id
    meta = sp.track(track_id)
    features = sp.audio_features(track_id)

    # meta
    name = meta['name']
    album = meta['album']['name']
    artist = meta['album']['artists'][0]['name']
    artist_id = meta['album']['artists'][0]['id']
    release_date = meta['album']['release_date']
    length = meta['duration_ms']
    popularity = meta['popularity']

    # features
    key = features[0]['key']
    mode = features[0]['mode']
    acousticness = features[0]['acousticness']
    danceability = features[0]['danceability']
    energy = features[0]['energy']
    valence = features[0]['valence']
    instrumentalness = features[0]['instrumentalness']
    liveness = features[0]['liveness']
    loudness = features[0]['loudness']
    speechiness = features[0]['speechiness']
    tempo = features[0]['tempo']
    time_signature = features[0]['time_signature']

    track = [t_id,
             artist_id,
             name,
             album,
             artist,
             release_date,
             length,
             popularity,
             key,
             mode,
             acousticness,
             danceability,
             energy,
             valence,
             instrumentalness,
             liveness,
             loudness,
             speechiness,
             tempo,
             time_signature]
    return track

# parse features
track_features = []
for i in range(len(track_list)):
    track = getTrackFeatures(track_list[i])
    track_features.append(track)

# build dataframe
df = pd.DataFrame(track_features,
                  columns = ['track_id',
                             'artist_id',
                             'name',
                             'album',
                             'artist',
                             'release_date',
                             'length',
                             'popularity',
                             'key',
                             'mode',
                             'acousticness',
                             'danceability',
                             'energy',
                             'valence',
                             'instrumentalness',
                             'liveness',
                             'loudness',
                             'speechiness',
                             'tempo',
                             'time_signature'])

# squish popularity to be in the same scale as the other features
# squish length to be measured in minutes
df['popularity'] = df['popularity'] / 100
df['length'] = (df['length'] / 1000) / 60

df.head()
# Out:
#                  track_id               artist_id              name  \
# 0  7LkxDAm3CxOMSFDZcRx0kI  5EHvXKnNz78jkAVgTQLQ5O  The Lesser Faith
# 1  23pLHGVFWELvxIiw0CQMaX  1xUhNgw4eJDZfvumIpcz1B       Hatebreeder
# 2  2dzCUvvliKLw9dj84IRlAg  1xUhNgw4eJDZfvumIpcz1B  Towards Dead End
# 3  4ueVppRcLrdLdL7sQTHhWb  4EvbQBS99RXzFGGimAS3i9           Eternal
# 4  4Lgj2JWNhM5DTWAMhz34AS  2UOVgpgiNTC6KK0vSC77aD             Sampo
#
#          album             artist release_date    length  popularity  key  \
# 0      Fiction  Dark Tranquillity   2007-09-26  4.630433        0.35    7
# 1  Hatebreeder  Children Of Bodom   1999-05-04  4.319550        0.44    7
# 2  Hatebreeder  Children Of Bodom   1999-05-04  4.901100        0.39    2
# 3      Epsilon  Blood Stain Child   2011-06-30  4.498000        0.27    1
# 4    Skyforger           Amorphis   2009-05-29  6.147333        0.16    7
#
#    mode  acousticness  danceability  energy  valence  instrumentalness  \
# 0     1      0.000025         0.411   0.965    0.422            0.2160
# 1     0      0.000275         0.417   0.976    0.638            0.8370
# 2     0      0.000156         0.188   0.949    0.538            0.8390
# 3     1      0.000021         0.508   0.977    0.305            0.0145
# 4     1      0.000060         0.159   0.763    0.269            0.0257
#
#    liveness  loudness  speechiness    tempo  time_signature
# 0     0.063    -4.503       0.0565  159.993               4
# 1     0.387    -3.196       0.0507  111.709               4
# 2     0.320    -2.490       0.0599  108.075               4
# 3     0.162    -4.582       0.0709  104.993               4
# 4     0.812    -4.462       0.0390  175.869               3

# %%
df.describe()
# Out:
#           length  popularity        key       mode  acousticness  \
# count  75.000000   75.000000  75.000000  75.000000     75.000000
# mean    5.201763    0.289067   5.786667   0.386667      0.000695
# std     1.480261    0.137184   3.739104   0.490266      0.003196
# min     3.422667    0.000000   0.000000   0.000000      0.000001
# 25%     4.345442    0.180000   2.000000   0.000000      0.000008
# 50%     4.819900    0.300000   7.000000   0.000000      0.000055
# 75%     5.435400    0.390000   9.000000   1.000000      0.000211
# max    11.657767    0.630000  11.000000   1.000000      0.027100
#
#        danceability     energy    valence  instrumentalness   liveness  \
# count     75.000000  75.000000  75.000000         75.000000  75.000000
# mean       0.356847   0.933493   0.252531          0.285281   0.239961
# std        0.117077   0.073427   0.146089          0.323735   0.199103
# min        0.097500   0.685000   0.034500          0.000000   0.045000
# 25%        0.256000   0.927000   0.138000          0.011860   0.110000
# 50%        0.390000   0.963000   0.222000          0.130000   0.160000
# 75%        0.447500   0.979000   0.320500          0.561000   0.308000
# max        0.557000   0.995000   0.638000          0.947000   0.941000
#
#         loudness  speechiness       tempo  time_signature
# count  75.000000    75.000000   75.000000       75.000000
# mean   -4.370280     0.090411  126.177573        3.800000
# std     1.456061     0.056537   29.506045        0.402694
# min    -7.971000     0.030600   87.564000        3.000000
# 25%    -5.175500     0.057150  104.966000        4.000000
# 50%    -4.339000     0.074000  119.425000        4.000000
# 75%    -3.237500     0.111500  144.757500        4.000000
# max    -1.409000     0.406000  199.915000        4.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          75 non-null     object
#  1   artist_id         75 non-null     object
#  2   name              75 non-null     object
#  3   album             75 non-null     object
#  4   artist            75 non-null     object
#  5   release_date      75 non-null     object
#  6   length            75 non-null     float64
#  7   popularity        75 non-null     float64
#  8   key               75 non-null     int64
#  9   mode              75 non-null     int64
#  10  acousticness      75 non-null     float64
#  11  danceability      75 non-null     float64
#  12  energy            75 non-null     float64
#  13  valence           75 non-null     float64
#  14  instrumentalness  75 non-null     float64
#  15  liveness          75 non-null     float64
#  16  loudness          75 non-null     float64
#  17  speechiness       75 non-null     float64
#  18  tempo             75 non-null     float64
#  19  time_signature    75 non-null     int64
# dtypes: float64(11), int64(3), object(6)
# memory usage: 11.8+ KB

# %%
# drop object variables
preprocess = df.drop(df.select_dtypes('object'), axis = 1)

# convert int64 to categoryical variables
int64 = preprocess.select_dtypes('int64')
for x in int64:
    preprocess[x] = preprocess[x].astype('category')
preprocess.head()
# Out:
#      length  popularity key mode  acousticness  danceability  energy  valence  \
# 0  4.630433        0.35   7    1      0.000025         0.411   0.965    0.422
# 1  4.319550        0.44   7    0      0.000275         0.417   0.976    0.638
# 2  4.901100        0.39   2    0      0.000156         0.188   0.949    0.538
# 3  4.498000        0.27   1    1      0.000021         0.508   0.977    0.305
# 4  6.147333        0.16   7    1      0.000060         0.159   0.763    0.269
#
#    instrumentalness  liveness  loudness  speechiness    tempo time_signature
# 0            0.2160     0.063    -4.503       0.0565  159.993              4
# 1            0.8370     0.387    -3.196       0.0507  111.709              4
# 2            0.8390     0.320    -2.490       0.0599  108.075              4
# 3            0.0145     0.162    -4.582       0.0709  104.993              4
# 4            0.0257     0.812    -4.462       0.0390  175.869              3

# %%
# returns homogenity scores added to the original dataframe

# prevents errors if rerunning analysis
if 'scores' in df.columns:
    df = df.drop(['scores'], axis = 1)

# Isolation Forest analysis    
model = IsolationForest(n_estimators = 500,
                        max_samples = 'auto',
                        contamination = 0.05, # assumes bottom 5% as outliers
                        n_jobs = -1,
                        random_state = 21)
model.fit(preprocess)
df['scores'] = model.decision_function(preprocess)
rank(df)
# Out:
#       scores                                               name  \
# 21  0.152789                          Where The Last Wave Broke
# 49  0.134149                                 Through The Shadow
# 63  0.133181                               Enhance My Nightmare
# 0   0.132269                                   The Lesser Faith
# 39  0.131740                                Sum Of The Universe
# 6   0.129903                               Nihilistic Overdrive
# 25  0.129193                                             Voices
# 42  0.127836                                   Crimson Symphony
# 3   0.125857                                            Eternal
# 53  0.122369                                   The Second Flame
# 26  0.120410                                        Metropolice
# 72  0.117189                Deviate from the Form - Bonus Track
# 62  0.115762                                The Harmony Remains
# 15  0.115278                           May Today Become the Day
# 54  0.113526                                   Sons Of Thoughts
# 61  0.106866                                       Heroes To Us
# 52  0.106847                                  New World Shadows
# 22  0.106765                                  Celestial Furnace
# 47  0.105740                                  Reflect The Storm
# 7   0.103277                                   Beauty of Malice
# 17  0.102736                               Petrichor by Sulphur
# 32  0.101795                     Kings of the Carnival Creation
# 28  0.101110                                 This Is Absolution
# 33  0.099510                                          Stålfågel
# 69  0.098858                                        Shadowchild
# 16  0.092234                                    End of the Road
# 64  0.091940                                            Nemesis
# 57  0.090021                        Supreme Pain For The Tyrant
# 37  0.090014                                     Lost to Apathy
# 14  0.088185         Ghost Prototype I - Measurement of Thought
# 9   0.088153                                   Devoid Of Caring
# 36  0.087937                                       Suicide Code
# 38  0.083610                                Fractured Archetype
# 51  0.078716                             Killing Me Killing You
# 58  0.074968                                        Broken Jade
# 66  0.073762  The Haunting (Somewhere in Time) [feat. Simone...
# 31  0.073485                               The End of Heartache
# 23  0.072858                               Monochromatic Stains
# 74  0.072179                            Returning to the Source
# 18  0.071142                   Square Nothing - 2020 Remastered
# 35  0.070628                                 The Arms of Sorrow
# 2   0.066270                                   Towards Dead End
# 56  0.066197                                          The Smoke
# 44  0.066094                                     Losers' Ballet
# 46  0.064499                                         Red Clouds
# 27  0.062285                                      Timewave Zero
# 24  0.060756                                      Heir Apparent
# 1   0.060754                                        Hatebreeder
# 11  0.059346                                      Surge Of Pity
# 29  0.053258                                  Grown Of Creation
# 8   0.051056                                         Ever Dying
# 43  0.050808                                  Martyr To Science
# 59  0.049683                       Sleep Well the Darkest Night
# 73  0.047150                        Red Light In My Eyes, Pt. 2
# 12  0.043500                                          Reconcile
# 19  0.043035                                           With You
# 65  0.043029                                  Summer Dying Fast
# 13  0.042362                                              Bleak
# 5   0.041201                                 In Death's Embrace
# 71  0.040073                                   Rikki Tikki Tavi
# 34  0.034892                                        In Aeternum
# 30  0.034752                                              Sugar
# 41  0.034685                                              Elegy
# 67  0.029926                            Tsunami and Submergence
# 68  0.026937    Gray Matter Mechanics - Apassionata Ex Machinea
# 70  0.024200                     Self vs Self (feat. In Flames)
# 48  0.023358                                        I Transpire
# 20  0.013549                              Deliberation - Studio
# 60  0.011222                              Parasites Of Paradise
# 55  0.009529                                   Mind as Universe
# 45  0.007353                                    Hybrid Stigmata
# 50 -0.017158                         Reverie / Harlequin Forest
# 4  -0.018615                                              Sampo
# 10 -0.032614                                          New Night
# 40 -0.067168                   Minotaur (The Wrath of Poseidon)
#
#                  artist                                        album  \
# 21            Insomnium                              Across The Dark
# 49            Insomnium                               One For Sorrow
# 63      Sonic Syndicate                                    Eden Fire
# 0     Dark Tranquillity                                      Fiction
# 39            Universum                              Mortuus Machina
# 6      Disarmonia Mundi               Mind Tricks (Extended Version)
# 25      Machinemade God                                       Masked
# 42    Blood Stain Child                     Silence of Northern Hell
# 3     Blood Stain Child                                      Epsilon
# 53      Omnium Gatherum                                 The Redshift
# 26    Blood Stain Child                                       Mozaiq
# 72        Scar Symmetry                         Pitch Black Progress
# 62  Mors Principium Est                                   The Unborn
# 15            Sentenced                            The Funeral Album
# 54      Omnium Gatherum  Spirits And August Lights / Steal The Light
# 61               Kalmah                                    Swampsong
# 52      Omnium Gatherum                            New World Shadows
# 22     Disarmonia Mundi               Mind Tricks (Extended Version)
# 47            In Flames                                 Come Clarity
# 7             Graveworm                            Engraved in Black
# 17             Soilwork                            The Ride Majestic
# 32         Dimmu Borgir            Puritanical Euphoric Misanthropia
# 28    Killswitch Engage                             As Daylight Dies
# 33             Soilwork                                     Feverish
# 69             Soilwork             A Predator's Portrait (Reloaded)
# 16            Sentenced                            The Funeral Album
# 64      Cradle Of Filth                                 Nymphetamine
# 57             CHTHONIC                                       Bù-Tik
# 37    Dark Tranquillity                                    Character
# 14        Scar Symmetry                         Holographic Universe
# 9             Insomnium                      Above The Weeping World
# 36            Graveworm                            Collateral Defect
# 38            Universum                              Mortuus Machina
# 51            Sentenced                       Killing Me Killing You
# 58             CHTHONIC                                Takasago Army
# 66              Kamelot                               The Black Halo
# 31    Killswitch Engage       The End of Heartache (Special Edition)
# 23    Dark Tranquillity                                  Damage Done
# 74            Persefone                          Spiritual Migration
# 18            In Flames           Clayman (20th Anniversary Edition)
# 35    Killswitch Engage           As Daylight Dies (Special Edition)
# 2     Children Of Bodom                                  Hatebreeder
# 56             Amorphis                                      Eclipse
# 44             Deadlock                                       Wolves
# 46     Disarmonia Mundi                    Fragments Of D-Generation
# 27        Scar Symmetry                         Holographic Universe
# 24                Opeth                  Watershed (Special Edition)
# 1     Children Of Bodom                                  Hatebreeder
# 11            Nightrage                        A New Disease Is Born
# 29             Deadlock                                       Wolves
# 8             In Flames                                 Subterranean
# 43             Deadlock                                    Manifesto
# 59       Logical Terror                                Ashes of Fate
# 73    Children Of Bodom                               Something Wild
# 12            Nightrage                        A New Disease Is Born
# 19      Machinemade God                                       Masked
# 65      Cradle Of Filth                     Bitter Suites to Succubi
# 13                Opeth                              Blackwater Park
# 5          Dimmu Borgir                 Enthrone Darkness Triumphant
# 71      Fair To Midland                             Arrows & Anchors
# 34  Fleshgod Apocalypse                                         King
# 30  Fleshgod Apocalypse                                       Veleno
# 41             Amorphis                                        Elegy
# 67            Allegaeon                                    Apoptosis
# 68            Allegaeon                      Proponent for Sentience
# 70             Pendulum                                    Immersion
# 48            Katatonia    Last Fair Deal Gone Down (Deluxe Edition)
# 20            Katatonia                      The Great Cold Distance
# 60  Mors Principium Est                                   The Unborn
# 55            Persefone                          Spiritual Migration
# 45         Dimmu Borgir            Puritanical Euphoric Misanthropia
# 50                Opeth                               Ghost Reveries
# 4              Amorphis                                    Skyforger
# 10            Katatonia                         Night Is the New Day
# 40  Fleshgod Apocalypse                                    Labyrinth
#
#                   track_id
# 21  1FQtNCA2nYXEeZ41Z4XyH7
# 49  4bOX3KfGgQE1GkxxJ3OUtI
# 63  2XD4NowUR2fQHNTF2FO1T5
# 0   7LkxDAm3CxOMSFDZcRx0kI
# 39  5UqR2S9N3RTYNmpnpEYCwj
# 6   0wD8PBXXq3cDndyhu0SX9D
# 25  4UiUd7ClIzWK0r3qkswGc6
# 42  49Cc4uBdMIPPDDjmcn8DLb
# 3   4ueVppRcLrdLdL7sQTHhWb
# 53  4YKY4vsi5tJKK2KsNY4zO5
# 26  5Dr8bgZuyfI5Nki04oYz2x
# 72  17mh54ovFWLJQKgFnpRnSP
# 62  09PDLrMCcoClfbnXrCBmMy
# 15  03hUjXfWyepgPxWfBsrG0r
# 54  3tmXnVTDKLsaiuXuSv6AwN
# 61  1xFrfYd7PHXTAriPTOfxL8
# 52  63iczcpxd8c5aV8Yqsn8MD
# 22  2NM3ydi7uBrhux2mYK2lrI
# 47  7kPVWNVbEUsguLRWRk8W33
# 7   3kaEzsEQ6JweUJwzjpCCce
# 17  2v4gF2JIQXqdbVpZiyvDHj
# 32  7x9gPXIuiG4K45JGR1Zqyq
# 28  53ZwCHcVQ5hOk4wFNDgmzn
# 33  4u4qXxJXwqUQfrvr8FXGHj
# 69  10iJFxrM8Pbhtqw7TGTZdi
# 16  7jeQrf3YHkMBftGajj8Wqm
# 64  4NFa3dMT0FhJ4yJkCdMPwz
# 57  7fX3rcplzuNOF7YPsUTQTE
# 37  0yRRVy4pI3Oa1qqqUpuGME
# 14  0QEHU9mrMu45022YLSi01o
# 9   6xPwcnwKGZfeLxCHMtbVhu
# 36  7ddRAfvlc1UG3HZ8Fi9Hku
# 38  6GxHsAEPjTR9zyI0rV4LAl
# 51  5ceYVTBWOXrxuwzkrkS4ob
# 58  37VeO4NGjwGaHMlfOK7eFW
# 66  4riKzzeTonEgPN9OCCvMqQ
# 31  2nUy0ifVE7UwtOK4rugFsP
# 23  2OhnDHT5LGG0ZAnjFEBsbg
# 74  372diRsJu7fxKmVuuH02kC
# 18  5n2wvt1G5ywxT1y6LGuDJB
# 35  42lC6bnDdAjRqZtsFe1tmg
# 2   2dzCUvvliKLw9dj84IRlAg
# 56  5tTV0Z32WckGngHWSbghTn
# 44  0ajbDpi2CQ9sl2uBMUSNpj
# 46  094NGfQ6CvvN7uM0aC8tAi
# 27  3NMLi31rokgkE7YilcM0B9
# 24  6OGkZoqso1wbIy5O6cV56N
# 1   23pLHGVFWELvxIiw0CQMaX
# 11  5S3OzvGuRpK7HrjQqKreCd
# 29  3JDbNcCA0sqls4hQCKY8ph
# 8   3HnwTO5lY1TeWYzFcnM4Eh
# 43  22FQS8s7RyroEWsidsGnAg
# 59  5i30fpdkqG28N9D2wThwdP
# 73  6MM6J46UQqXE4nz37UOGWL
# 12  34ss3R4VC7PO7c0xJnK7ZZ
# 19  6wdlDku4keVEE6pVFvPdCa
# 65  4xGL0QDJxlGhLKXmHso1Ie
# 13  294Qb8EGfUjmZhaxROiLiV
# 5   33Tw7bBpn08xmigGaruVhL
# 71  1NAYWRWQhEglu5MvcCjsJo
# 34  4etOTfwzJCDQVUbLJqg2kF
# 30  3f4VN0IHlMyMRVtnbiVqm3
# 41  1i1X96hevCrjhapdlIkSy4
# 67  2IFNfSqJqygGPE38aJn5sh
# 68  2ZYsMOE4QpWICp8LQR6iku
# 70  2lN6G35gsXkA3xzPYqmis5
# 48  5FSlmn3QXiIbc3i1OHJLDa
# 20  3z7jm3G3rdp05oTzYWkHNi
# 60  1Hq0JyflW9EE2HR7rU6jOJ
# 55  12pdTPMSl9W97GbWJZZEqY
# 45  5oKvrJSRVxwAvnWERfZ0aE
# 50  0cgz0Fa7bivUEwqI5Srj1P
# 4   4Lgj2JWNhM5DTWAMhz34AS
# 10  6gOPxIln3rnSiBiGEApiak
# 40  3sizVMerlajPegOZWbMKwZ

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          75 non-null     object
#  1   artist_id         75 non-null     object
#  2   name              75 non-null     object
#  3   album             75 non-null     object
#  4   artist            75 non-null     object
#  5   release_date      75 non-null     object
#  6   length            75 non-null     float64
#  7   popularity        75 non-null     float64
#  8   key               75 non-null     int64
#  9   mode              75 non-null     int64
#  10  acousticness      75 non-null     float64
#  11  danceability      75 non-null     float64
#  12  energy            75 non-null     float64
#  13  valence           75 non-null     float64
#  14  instrumentalness  75 non-null     float64
#  15  liveness          75 non-null     float64
#  16  loudness          75 non-null     float64
#  17  speechiness       75 non-null     float64
#  18  tempo             75 non-null     float64
#  19  time_signature    75 non-null     int64
#  20  scores            75 non-null     float64
# dtypes: float64(12), int64(3), object(6)
# memory usage: 12.4+ KB

# %%
# drop object variables
preprocess = df.drop(df.select_dtypes('object'), axis = 1)

# convert int64 to categoryical variables
int64 = preprocess.select_dtypes('int64')
for x in int64:
    preprocess[x] = preprocess[x].astype('category')
preprocess.head()
# Out:
#      length  popularity key mode  acousticness  danceability  energy  valence  \
# 0  4.630433        0.35   7    1      0.000025         0.411   0.965    0.422
# 1  4.319550        0.44   7    0      0.000275         0.417   0.976    0.638
# 2  4.901100        0.39   2    0      0.000156         0.188   0.949    0.538
# 3  4.498000        0.27   1    1      0.000021         0.508   0.977    0.305
# 4  6.147333        0.16   7    1      0.000060         0.159   0.763    0.269
#
#    instrumentalness  liveness  loudness  speechiness    tempo time_signature  \
# 0            0.2160     0.063    -4.503       0.0565  159.993              4
# 1            0.8370     0.387    -3.196       0.0507  111.709              4
# 2            0.8390     0.320    -2.490       0.0599  108.075              4
# 3            0.0145     0.162    -4.582       0.0709  104.993              4
# 4            0.0257     0.812    -4.462       0.0390  175.869              3
#
#      scores
# 0  0.132269
# 1  0.060754
# 2  0.066270
# 3  0.125857
# 4 -0.018615

# %%
# returns pvalues for linear regression model
Y = preprocess['scores'].values
X = preprocess.drop(['scores'], axis = 1).values

model = sm.OLS(Y, X, missing='drop')
model_result = model.fit()

pvalues = list(model_result.pvalues)
headers = list((preprocess.drop(['scores'], axis = 1)).columns)

for i in range(len(pvalues)):
    pvalues[i] = round(pvalues[i], 3)

headers_pvalues = dict(zip(headers, pvalues))  
headers_pvalues
# Out:
# {'length': 0.01,
#  'popularity': 0.038,
#  'key': 0.74,
#  'mode': 0.82,
#  'acousticness': 0.0,
#  'danceability': 0.941,
#  'energy': 0.0,
#  'valence': 0.019,
#  'instrumentalness': 0.007,
#  'liveness': 0.001,
#  'loudness': 0.009,
#  'speechiness': 0.0,
#  'tempo': 0.0,
#  'time_signature': 0.0}

# %%
# returns any keys that are statistically insignificant
drops = {k:v for (k,v) in headers_pvalues.items() if v > 0.05}
drop_keys = list(drops.keys())
drop_keys
# Out:
# ['key', 'mode', 'danceability']

# %%
# drop object variables
preprocess = df.drop(df.select_dtypes('object'), axis = 1)
preprocess = preprocess.drop(drop_keys, axis = 1)
# convert int64 to categoryical variables
int64 = preprocess.select_dtypes('int64')
for x in int64:
    preprocess[x] = preprocess[x].astype('category')
preprocess.head()
# Out:
#      length  popularity  acousticness  energy  valence  instrumentalness  \
# 0  4.630433        0.35      0.000025   0.965    0.422            0.2160
# 1  4.319550        0.44      0.000275   0.976    0.638            0.8370
# 2  4.901100        0.39      0.000156   0.949    0.538            0.8390
# 3  4.498000        0.27      0.000021   0.977    0.305            0.0145
# 4  6.147333        0.16      0.000060   0.763    0.269            0.0257
#
#    liveness  loudness  speechiness    tempo time_signature    scores
# 0     0.063    -4.503       0.0565  159.993              4  0.132269
# 1     0.387    -3.196       0.0507  111.709              4  0.060754
# 2     0.320    -2.490       0.0599  108.075              4  0.066270
# 3     0.162    -4.582       0.0709  104.993              4  0.125857
# 4     0.812    -4.462       0.0390  175.869              3 -0.018615

# %%
if 'scores' in preprocess.columns:
    predictions = preprocess.drop(['scores'], axis = 1)
else:
    predictions = preprocess

# create a pipeline    
predict_pipeline = make_pipeline(IsolationForest(n_estimators = (500),
                                                 max_samples = 'auto',
                                                 max_features = predictions.shape[1],
                                                 contamination = 0.05,
                                                 n_jobs = -1,
                                                 random_state = 21)
                                )
predict_pipeline.fit(predictions)

# save model as playlist_id.joblib
joblib.dump(predict_pipeline, str(playlist_id + '.joblib'))
clf = load('6vqdAph2gxHHgvojxM7js4.joblib')

scores = clf.decision_function(predictions)
df['scores'] = scores
rank(df)
# Out:
#       scores                                               name  \
# 21  0.172070                          Where The Last Wave Broke
# 3   0.170371                                            Eternal
# 49  0.154815                                 Through The Shadow
# 17  0.149748                               Petrichor by Sulphur
# 39  0.147419                                Sum Of The Universe
# 25  0.147241                                             Voices
# 53  0.146438                                   The Second Flame
# 63  0.145923                               Enhance My Nightmare
# 6   0.143037                               Nihilistic Overdrive
# 0   0.137714                                   The Lesser Faith
# 42  0.136245                                   Crimson Symphony
# 33  0.135062                                          Stålfågel
# 54  0.134355                                   Sons Of Thoughts
# 72  0.133817                Deviate from the Form - Bonus Track
# 26  0.133006                                        Metropolice
# 15  0.129405                           May Today Become the Day
# 62  0.125833                                The Harmony Remains
# 7   0.123568                                   Beauty of Malice
# 64  0.123544                                            Nemesis
# 52  0.122408                                  New World Shadows
# 22  0.121946                                  Celestial Furnace
# 16  0.115478                                    End of the Road
# 69  0.115251                                        Shadowchild
# 51  0.114846                             Killing Me Killing You
# 61  0.114281                                       Heroes To Us
# 47  0.108787                                  Reflect The Storm
# 32  0.107966                     Kings of the Carnival Creation
# 28  0.104963                                 This Is Absolution
# 9   0.104753                                   Devoid Of Caring
# 5   0.099276                                 In Death's Embrace
# 37  0.098109                                     Lost to Apathy
# 31  0.096924                               The End of Heartache
# 36  0.096864                                       Suicide Code
# 57  0.095750                        Supreme Pain For The Tyrant
# 58  0.094711                                        Broken Jade
# 14  0.094349         Ghost Prototype I - Measurement of Thought
# 73  0.093413                        Red Light In My Eyes, Pt. 2
# 2   0.088695                                   Towards Dead End
# 18  0.084738                   Square Nothing - 2020 Remastered
# 66  0.084046  The Haunting (Somewhere in Time) [feat. Simone...
# 56  0.081985                                          The Smoke
# 23  0.081865                               Monochromatic Stains
# 38  0.076042                                Fractured Archetype
# 27  0.073999                                      Timewave Zero
# 35  0.071175                                 The Arms of Sorrow
# 24  0.069867                                      Heir Apparent
# 29  0.068508                                  Grown Of Creation
# 74  0.067637                            Returning to the Source
# 44  0.067172                                     Losers' Ballet
# 46  0.061979                                         Red Clouds
# 43  0.058469                                  Martyr To Science
# 11  0.058195                                      Surge Of Pity
# 30  0.045172                                              Sugar
# 1   0.044909                                        Hatebreeder
# 12  0.044262                                          Reconcile
# 59  0.044194                       Sleep Well the Darkest Night
# 65  0.039839                                  Summer Dying Fast
# 45  0.039090                                    Hybrid Stigmata
# 55  0.036376                                   Mind as Universe
# 67  0.035908                            Tsunami and Submergence
# 41  0.034245                                              Elegy
# 71  0.033904                                   Rikki Tikki Tavi
# 19  0.031050                                           With You
# 34  0.024944                                        In Aeternum
# 8   0.024356                                         Ever Dying
# 60  0.021322                              Parasites Of Paradise
# 20  0.017408                              Deliberation - Studio
# 13  0.017161                                              Bleak
# 68  0.017067    Gray Matter Mechanics - Apassionata Ex Machinea
# 48  0.016480                                        I Transpire
# 70  0.012455                     Self vs Self (feat. In Flames)
# 4  -0.029062                                              Sampo
# 50 -0.035671                         Reverie / Harlequin Forest
# 10 -0.039145                                          New Night
# 40 -0.086155                   Minotaur (The Wrath of Poseidon)
#
#                  artist                                        album  \
# 21            Insomnium                              Across The Dark
# 3     Blood Stain Child                                      Epsilon
# 49            Insomnium                               One For Sorrow
# 17             Soilwork                            The Ride Majestic
# 39            Universum                              Mortuus Machina
# 25      Machinemade God                                       Masked
# 53      Omnium Gatherum                                 The Redshift
# 63      Sonic Syndicate                                    Eden Fire
# 6      Disarmonia Mundi               Mind Tricks (Extended Version)
# 0     Dark Tranquillity                                      Fiction
# 42    Blood Stain Child                     Silence of Northern Hell
# 33             Soilwork                                     Feverish
# 54      Omnium Gatherum  Spirits And August Lights / Steal The Light
# 72        Scar Symmetry                         Pitch Black Progress
# 26    Blood Stain Child                                       Mozaiq
# 15            Sentenced                            The Funeral Album
# 62  Mors Principium Est                                   The Unborn
# 7             Graveworm                            Engraved in Black
# 64      Cradle Of Filth                                 Nymphetamine
# 52      Omnium Gatherum                            New World Shadows
# 22     Disarmonia Mundi               Mind Tricks (Extended Version)
# 16            Sentenced                            The Funeral Album
# 69             Soilwork             A Predator's Portrait (Reloaded)
# 51            Sentenced                       Killing Me Killing You
# 61               Kalmah                                    Swampsong
# 47            In Flames                                 Come Clarity
# 32         Dimmu Borgir            Puritanical Euphoric Misanthropia
# 28    Killswitch Engage                             As Daylight Dies
# 9             Insomnium                      Above The Weeping World
# 5          Dimmu Borgir                 Enthrone Darkness Triumphant
# 37    Dark Tranquillity                                    Character
# 31    Killswitch Engage       The End of Heartache (Special Edition)
# 36            Graveworm                            Collateral Defect
# 57             CHTHONIC                                       Bù-Tik
# 58             CHTHONIC                                Takasago Army
# 14        Scar Symmetry                         Holographic Universe
# 73    Children Of Bodom                               Something Wild
# 2     Children Of Bodom                                  Hatebreeder
# 18            In Flames           Clayman (20th Anniversary Edition)
# 66              Kamelot                               The Black Halo
# 56             Amorphis                                      Eclipse
# 23    Dark Tranquillity                                  Damage Done
# 38            Universum                              Mortuus Machina
# 27        Scar Symmetry                         Holographic Universe
# 35    Killswitch Engage           As Daylight Dies (Special Edition)
# 24                Opeth                  Watershed (Special Edition)
# 29             Deadlock                                       Wolves
# 74            Persefone                          Spiritual Migration
# 44             Deadlock                                       Wolves
# 46     Disarmonia Mundi                    Fragments Of D-Generation
# 43             Deadlock                                    Manifesto
# 11            Nightrage                        A New Disease Is Born
# 30  Fleshgod Apocalypse                                       Veleno
# 1     Children Of Bodom                                  Hatebreeder
# 12            Nightrage                        A New Disease Is Born
# 59       Logical Terror                                Ashes of Fate
# 65      Cradle Of Filth                     Bitter Suites to Succubi
# 45         Dimmu Borgir            Puritanical Euphoric Misanthropia
# 55            Persefone                          Spiritual Migration
# 67            Allegaeon                                    Apoptosis
# 41             Amorphis                                        Elegy
# 71      Fair To Midland                             Arrows & Anchors
# 19      Machinemade God                                       Masked
# 34  Fleshgod Apocalypse                                         King
# 8             In Flames                                 Subterranean
# 60  Mors Principium Est                                   The Unborn
# 20            Katatonia                      The Great Cold Distance
# 13                Opeth                              Blackwater Park
# 68            Allegaeon                      Proponent for Sentience
# 48            Katatonia    Last Fair Deal Gone Down (Deluxe Edition)
# 70             Pendulum                                    Immersion
# 4              Amorphis                                    Skyforger
# 50                Opeth                               Ghost Reveries
# 10            Katatonia                         Night Is the New Day
# 40  Fleshgod Apocalypse                                    Labyrinth
#
#                   track_id
# 21  1FQtNCA2nYXEeZ41Z4XyH7
# 3   4ueVppRcLrdLdL7sQTHhWb
# 49  4bOX3KfGgQE1GkxxJ3OUtI
# 17  2v4gF2JIQXqdbVpZiyvDHj
# 39  5UqR2S9N3RTYNmpnpEYCwj
# 25  4UiUd7ClIzWK0r3qkswGc6
# 53  4YKY4vsi5tJKK2KsNY4zO5
# 63  2XD4NowUR2fQHNTF2FO1T5
# 6   0wD8PBXXq3cDndyhu0SX9D
# 0   7LkxDAm3CxOMSFDZcRx0kI
# 42  49Cc4uBdMIPPDDjmcn8DLb
# 33  4u4qXxJXwqUQfrvr8FXGHj
# 54  3tmXnVTDKLsaiuXuSv6AwN
# 72  17mh54ovFWLJQKgFnpRnSP
# 26  5Dr8bgZuyfI5Nki04oYz2x
# 15  03hUjXfWyepgPxWfBsrG0r
# 62  09PDLrMCcoClfbnXrCBmMy
# 7   3kaEzsEQ6JweUJwzjpCCce
# 64  4NFa3dMT0FhJ4yJkCdMPwz
# 52  63iczcpxd8c5aV8Yqsn8MD
# 22  2NM3ydi7uBrhux2mYK2lrI
# 16  7jeQrf3YHkMBftGajj8Wqm
# 69  10iJFxrM8Pbhtqw7TGTZdi
# 51  5ceYVTBWOXrxuwzkrkS4ob
# 61  1xFrfYd7PHXTAriPTOfxL8
# 47  7kPVWNVbEUsguLRWRk8W33
# 32  7x9gPXIuiG4K45JGR1Zqyq
# 28  53ZwCHcVQ5hOk4wFNDgmzn
# 9   6xPwcnwKGZfeLxCHMtbVhu
# 5   33Tw7bBpn08xmigGaruVhL
# 37  0yRRVy4pI3Oa1qqqUpuGME
# 31  2nUy0ifVE7UwtOK4rugFsP
# 36  7ddRAfvlc1UG3HZ8Fi9Hku
# 57  7fX3rcplzuNOF7YPsUTQTE
# 58  37VeO4NGjwGaHMlfOK7eFW
# 14  0QEHU9mrMu45022YLSi01o
# 73  6MM6J46UQqXE4nz37UOGWL
# 2   2dzCUvvliKLw9dj84IRlAg
# 18  5n2wvt1G5ywxT1y6LGuDJB
# 66  4riKzzeTonEgPN9OCCvMqQ
# 56  5tTV0Z32WckGngHWSbghTn
# 23  2OhnDHT5LGG0ZAnjFEBsbg
# 38  6GxHsAEPjTR9zyI0rV4LAl
# 27  3NMLi31rokgkE7YilcM0B9
# 35  42lC6bnDdAjRqZtsFe1tmg
# 24  6OGkZoqso1wbIy5O6cV56N
# 29  3JDbNcCA0sqls4hQCKY8ph
# 74  372diRsJu7fxKmVuuH02kC
# 44  0ajbDpi2CQ9sl2uBMUSNpj
# 46  094NGfQ6CvvN7uM0aC8tAi
# 43  22FQS8s7RyroEWsidsGnAg
# 11  5S3OzvGuRpK7HrjQqKreCd
# 30  3f4VN0IHlMyMRVtnbiVqm3
# 1   23pLHGVFWELvxIiw0CQMaX
# 12  34ss3R4VC7PO7c0xJnK7ZZ
# 59  5i30fpdkqG28N9D2wThwdP
# 65  4xGL0QDJxlGhLKXmHso1Ie
# 45  5oKvrJSRVxwAvnWERfZ0aE
# 55  12pdTPMSl9W97GbWJZZEqY
# 67  2IFNfSqJqygGPE38aJn5sh
# 41  1i1X96hevCrjhapdlIkSy4
# 71  1NAYWRWQhEglu5MvcCjsJo
# 19  6wdlDku4keVEE6pVFvPdCa
# 34  4etOTfwzJCDQVUbLJqg2kF
# 8   3HnwTO5lY1TeWYzFcnM4Eh
# 60  1Hq0JyflW9EE2HR7rU6jOJ
# 20  3z7jm3G3rdp05oTzYWkHNi
# 13  294Qb8EGfUjmZhaxROiLiV
# 68  2ZYsMOE4QpWICp8LQR6iku
# 48  5FSlmn3QXiIbc3i1OHJLDa
# 70  2lN6G35gsXkA3xzPYqmis5
# 4   4Lgj2JWNhM5DTWAMhz34AS
# 50  0cgz0Fa7bivUEwqI5Srj1P
# 10  6gOPxIln3rnSiBiGEApiak
# 40  3sizVMerlajPegOZWbMKwZ

# %%
# returns spotify recomendations for the most homogenous tracks in the playlist
refresh()
seed_tracks = rank(df)[:5]['track_id'].tolist()
seed_rec = sp.recommendations(seed_tracks = seed_tracks, limit = 100)

rec_list = []
for i in range(len(seed_rec['tracks'])):
    ids = seed_rec['tracks'][i]['id']
    rec_list.append(ids)
rec_list[:5]
# Out:
# ['3d9hmArOgeP3iBHEaOL15O',
#  '5yEVh1qPpp1pvNarqJPYwo',
#  '63H2QSdtZPc3BA6e2IrvvW',
#  '44mommx98x2Dh3Ud9fdbym',
#  '73vyulFUPAla99D1wUtMQo']

# %%
track_features = []
for i in range(len(rec_list)):
    track = getTrackFeatures(rec_list[i])
    track_features.append(track)

# build dataframe
rec_df = pd.DataFrame(track_features,
                  columns = ['track_id',
                             'artist_id',
                             'name',
                             'album',
                             'artist',
                             'release_date',
                             'length',
                             'popularity',
                             'key',
                             'mode',
                             'acousticness',
                             'danceability',
                             'energy',
                             'valence',
                             'instrumentalness',
                             'liveness',
                             'loudness',
                             'speechiness',
                             'tempo',
                             'time_signature'])

# squish popularity to be in the same scale as the other features
# squish length to be measured in minutes
rec_df['popularity'] = rec_df['popularity'] / 100
rec_df['length'] = (rec_df['length'] / 1000) / 60

rec_df.head()
# Out:
#                  track_id               artist_id                      name  \
# 0  3d9hmArOgeP3iBHEaOL15O  4JNF6YOUi69O4zAdwQVGLY  Wings Of Feather And Wax
# 1  5yEVh1qPpp1pvNarqJPYwo  0iem9JStyv56PV2X7avZbo                Stormghost
# 2  63H2QSdtZPc3BA6e2IrvvW  1tcrgTKBUpGVRGnPz4breO          Whispering Deeps
# 3  44mommx98x2Dh3Ud9fdbym  7gTbq5nTZGQIUgjEGXQpOS  When the Lights Are Down
# 4  73vyulFUPAla99D1wUtMQo  3Meu28o8P5z9Zjm6NTGihT              Falling Snow
#
#                       album             artist release_date    length  \
# 0  Wings Of Feather And Wax   Killer Be Killed   2014-04-11  3.735850
# 1              Cold Inferno   Disarmonia Mundi   2015-06-09  4.413500
# 2            Inner Universe  Words Of Farewell   2020-03-31  5.807333
# 3            The Black Halo            Kamelot   2005-03-15  3.691100
# 4   Ashes Against The Grain           Agalloch   2006-08-15  9.646000
#
#    popularity  key  mode  acousticness  danceability  energy  valence  \
# 0        0.14    0     1      0.000037         0.256   0.964   0.2830
# 1        0.32    8     1      0.000005         0.403   0.987   0.1440
# 2        0.27    2     1      0.000087         0.402   0.981   0.0897
# 3        0.52   10     0      0.000056         0.303   0.939   0.3690
# 4        0.36   10     1      0.000007         0.184   0.987   0.1660
#
#    instrumentalness  liveness  loudness  speechiness    tempo  time_signature
# 0          0.000585    0.3510    -3.597       0.0919   92.469               4
# 1          0.000414    0.3850    -2.362       0.1110   98.016               4
# 2          0.310000    0.0687    -4.476       0.2160  120.042               4
# 3          0.012800    0.1080    -6.377       0.0671  169.970               4
# 4          0.585000    0.0859    -4.328       0.0736  131.129               4

# %%
# drop object variables
rec_preprocess = rec_df.drop(rec_df.select_dtypes('object'), axis = 1)
rec_preprocess = rec_preprocess.drop(drop_keys, axis = 1)

# convert int64 to categoryical variables
int64 = rec_preprocess.select_dtypes('int64')
for x in int64:
    rec_preprocess[x] = rec_preprocess[x].astype('category')
rec_preprocess.head()


if 'scores' in rec_preprocess.columns:
    rec_predictions = rec_preprocess.drop(['scores'], axis = 1)
else:
    rec_predictions = rec_preprocess
    
scores = clf.decision_function(rec_predictions)
rec_df['scores'] = scores
rank(rec_df)
# Out:
#       scores                                               name  \
# 29  0.154815                                 Through The Shadow
# 98  0.149192                                  Blade Reflections
# 32  0.145093                            Strenght from My Wounds
# 73  0.145078                                          Afterlife
# 58  0.143206                               Ascend to the Throne
# 40  0.142138                                   Death in General
# 97  0.140400                                       Frozen Angel
# 76  0.139749                                    Midnight Runner
# 39  0.138885                                          In Sorrow
# 19  0.136988                                        Unbreakable
# 99  0.135866                                     Eye for an Eye
# 41  0.134238                                             Dynamo
# 51  0.130112                               The Nurturing Glance
# 78  0.125340                                   Decoding Reality
# 23  0.124906                                    My Allied Ocean
# 91  0.123839                              Preaching the Machine
# 60  0.123204                                    Legion Of Beast
# 18  0.120922                                             Eraser
# 1   0.119770                                         Stormghost
# 68  0.118269                                      Enemy Unbound
# 34  0.117653                                         Pathfinder
# 30  0.117511                          Sinne missä aamu sarastaa
# 0   0.117189                           Wings Of Feather And Wax
# 82  0.115110                                   Her Frantic Call
# 57  0.113601                                     Hold the Sword
# 38  0.112909                                  The Silent Divide
# 11  0.111117                                  Face the Colossus
# 2   0.110314                                   Whispering Deeps
# 50  0.110293                                      24 Hours Left
# 62  0.109164                           Home Is Where the Sty Is
# 65  0.108237                              The Living Infinite I
# 54  0.108058                                              Grief
# 79  0.106399                                           Helsinki
# 15  0.105996                                            Enclave
# 46  0.105060                                          Blankness
# 56  0.103191                                        Yara's Song
# 14  0.098974                                    Telltale Notion
# 5   0.098933                                          Avalanche
# 85  0.096370                                      Silent Waters
# 83  0.095375                                Liberation In Death
# 21  0.093794                                  Inherit the Earth
# 22  0.092312                             The Pursuit Of Vikings
# 17  0.091207                                       Human Nature
# 70  0.090898                                   Suffering Quotes
# 33  0.089122                               Hallowed Be Thy Name
# 13  0.087691                         One Thousand Years of Rain
# 3   0.086533                           When the Lights Are Down
# 8   0.085687                                             Aurora
# 48  0.082490                                       The Reticent
# 4   0.082287                                       Falling Snow
# 74  0.080826                                         April Rain
# 81  0.079359                                         Departures
# 12  0.078008                             The Living Infinite II
# 71  0.077783                                 Psychotic Euphoric
# 24  0.077145                                 Veil Walled Garden
# 87  0.076042                                Fractured Archetype
# 20  0.075718                             Divided.. Conquer Them
# 44  0.075478                                     Edge and Pearl
# 75  0.073909                                      Six Feet Deep
# 26  0.073875                                  Shut Down With Me
# 42  0.073655                                       Subdivisions
# 67  0.072566                                              Ruins
# 63  0.071848                                      The Last Time
# 89  0.071047                                         Regenerate
# 16  0.070644                                             EXCEED
# 52  0.070459                                       Rx Overdrive
# 64  0.070265                                        Pinball Map
# 47  0.070152                                           Colossus
# 96  0.066975                                     I Am the Abyss
# 45  0.066937                                   End of an Empire
# 90  0.066592                                              Sonne
# 6   0.065716                                 Breaking the Limit
# 35  0.064560                       Death Put a Smile on My Face
# 28  0.064124                                          Wasteland
# 37  0.062786                                At War with Reality
# 55  0.061979                                         Red Clouds
# 9   0.057650  Yomi yori kiko yu, kokoku no deung To homura n...
# 84  0.056992                                      Cutting Teeth
# 92  0.054848                                             Reborn
# 49  0.052892                                       Illusion Now
# 27  0.048668                                          Salvation
# 86  0.047446                                          Two Weeks
# 95  0.042701                                          No Reason
# 53  0.039244                          Until the World Goes Cold
# 61  0.037581                          I´m Shipping Up To Boston
# 69  0.034292                                          The Shift
# 77  0.025717                                  Only for the Weak
# 31  0.023470                                              M1917
# 66  0.018999                                   The Reaper Waits
# 72  0.013938                                Point Zero Solution
# 7   0.010107                                           Deadsong
# 80  0.002143                                    Too Dark to See
# 88 -0.006113                            Thank You for the Demon
# 25 -0.012579                                      The Violation
# 36 -0.014079                                        Man & Earth
# 10 -0.018848                                   Own Little World
# 94 -0.021790                The Horizon Effect (feat. Mel Rose)
# 93 -0.021941                                    Old Heart Falls
# 43 -0.023950                And Plague Flowers the Kaleidoscope
# 59 -0.045378                                   Black Winter Day
#
#                             artist  \
# 29                       Insomnium
# 98                 Omnium Gatherum
# 32                          Lahmia
# 73                        Metalite
# 58                    Rise to Fall
# 40                        Soilwork
# 97                         Norther
# 76                        Mustasch
# 39                       Destinity
# 19               My Dear Addiction
# 99                  The Hypothesis
# 41                         Stam1na
# 51                        Soilwork
# 78                    Rise to Fall
# 23                        Evergrey
# 91                       Allegaeon
# 60         Eternal Tears Of Sorrow
# 18                       Hypocrisy
# 1                 Disarmonia Mundi
# 68                     The Absence
# 34                    The Unguided
# 30                          Mokoma
# 0                 Killer Be Killed
# 82                          Lahmia
# 57                       Whispered
# 38                        Anterior
# 11                          Dagoba
# 2                Words Of Farewell
# 50                   Cipher System
# 62                     Poisonblack
# 65                        Soilwork
# 54                  Pain Confessor
# 79                        Soilwork
# 15                 Sonic Syndicate
# 46                Fear My Thoughts
# 56                        Mustasch
# 14               Words Of Farewell
# 5                 Kill The Romance
# 85                        Amorphis
# 83                         Skyfire
# 21                    The Unguided
# 22                     Amon Amarth
# 17                       Degradead
# 70                      The Sorrow
# 33                 Cradle Of Filth
# 13                        Enslaved
# 3                          Kamelot
# 8                    Ghost Brigade
# 48                       Insomnium
# 4                         Agalloch
# 74                          Delain
# 81                   Ghost Brigade
# 12                        Soilwork
# 71                  Silent Descent
# 24               The Luna Sequence
# 87                       Universum
# 20                        Nonpoint
# 44              Machinae Supremacy
# 75                 Various Artists
# 26                     Ember Falls
# 42                       Allegaeon
# 67                    Shade Empire
# 63                All That Remains
# 89                    Fear Factory
# 16             NOCTURNAL BLOODLUST
# 52                      Crossfaith
# 64                       In Flames
# 47                       Borknagar
# 96                   Shylmagoghnar
# 45                     Celldweller
# 90                         Caliban
# 6                       Illidiance
# 35                    5 Star Grave
# 28                    Darkest Hour
# 37                    At The Gates
# 55                Disarmonia Mundi
# 9   Imperial Circus Dead Decadence
# 84                     The Haunted
# 92                   Fail Emotions
# 49                  The Hypothesis
# 27                           Engel
# 86                All That Remains
# 95                Callenish Circle
# 53                         Trivium
# 61               Children Of Bodom
# 69                Eye of the Enemy
# 77                       In Flames
# 31            a crowd of rebellion
# 66                         Mendeed
# 72                     Deals Death
# 7                  Before The Dawn
# 80                       Crystalic
# 88                        Mustasch
# 25             Fleshgod Apocalypse
# 36                     Raised Fist
# 10                     Celldweller
# 94                         Mechina
# 93                       Katatonia
# 43                 Ne Obliviscaris
# 59                        Amorphis
#
#                                                 album                track_id
# 29                                     One For Sorrow  4bOX3KfGgQE1GkxxJ3OUtI
# 98                                  Blade Reflections  02jmSLjpElhxW6w0waFQtw
# 32                                     Into the Abyss  4BFsNwlAP8AxLX4BOsTFlq
# 73                                     Heroes in Time  7E23KVVacUy7IXPwF60iZG
# 58                                   Defying the Gods  0wZPKoGk8ddgmgqVUXaWBc
# 40                                  The Ride Majestic  1suh3dQIhaJiHger91tDQ0
# 97                                                  N  0qwHMBslXUZo7ePfVYnU5X
# 76                                    Midnight Runner  4sHSGl11LQbHVynHu3p6JX
# 39                                  XI Reasons to See  7qQeldOEJZ5JLSN3L8VA9M
# 19                                        Unbreakable  4cOVDjeBdpQiU4Qolf9JXp
# 99                                             Origin  52ygtenQsKPjJLvp63XSsj
# 41                                                SLK  5mu5oz5S8DkWKEjzYs0Udy
# 51                                       Verkligheten  5EoXDEYfLTRAvaWX25tvDw
# 78                                   Defying the Gods  7wblhWFRa2J9isIoOAhFkk
# 23                                   The Storm Within  23LWwPj1HF3MeSDF7GGhPG
# 91                                            2008 EP  0z76WoplujZmszn7d6KGyn
# 60                                       Saivon lapsi  6T37SarFYXVJ1Ax5cT9g8e
# 18                                        The Arrival  3hnRbKie2CrjJmpAd30JlD
# 1                                        Cold Inferno  5yEVh1qPpp1pvNarqJPYwo
# 68                                      Enemy Unbound  1F1WcykBW6Evr7KnlgKDsc
# 34                                      Nightmareland  06JFzm5uOYqN3ziTD5OnLJ
# 30                                  Elävien kirjoihin  0uYv1tNoIHUt6XPjLME4cA
# 0                            Wings Of Feather And Wax  3d9hmArOgeP3iBHEaOL15O
# 82                                         Resilience  6ygSuWROQBO1y6UT4WEK4c
# 57                                  Shogunate Macabre  5Nh7kfjGQMgCfwu6IUv7df
# 38                                This Age of Silence  0EXS78qzX6xsopwHSyu2d7
# 11                                  Face the Colossus  4ixRXUirtDYHGkviLna87G
# 2                                      Inner Universe  63H2QSdtZPc3BA6e2IrvvW
# 50                               Central Tunnel Eight  23JgrdZ3HnciWtmpUQwWeD
# 62                                              Lyijy  2BYMBnZVHxxtwcnqpBfY2f
# 65                                The Living Infinite  5kyy5Z6U4RiwkWJtmmuew1
# 54                                       Incarcerated  23Da19AnW2Y6g6ZoKdz5R7
# 79                                    Death Resonance  70lEHTzNH2Ixwc0WDG3kpb
# 15                        Only Inhuman - Tour Edition  2GIh8nwczPZH4UrzSXK8vp
# 46                                           Vulcanus  3NXPPTAtYI6FKM2fsWcIv9
# 56                                       Testosterone  7erSxIT70eyaJ7bCMeb1Vc
# 14                              The Black Wild Yonder  14DNEud6RO6YHOBzfixWee
# 5                             For Rome And The Throne  4IjGQuMTjFEm5JC1MHmtRK
# 85                                      Silent Waters  3zPAdhL6WFpoVX8clabzkm
# 83                                Liberation In Death  5v4kf1CX7PcqM3Z459rhSL
# 21                                         Hell Frost  1QVOcF6a78YBc9MS2lH55l
# 22                                      Fate of Norns  0sObxZUKqdPfgjG9ahSlP5
# 17                                  A World Destroyer  7zL3cYPdd0BBx2DhGjBt6X
# 70                                         The Sorrow  1H72a37nCiKTfMyiPllIqV
# 33                           Lovecraft & Witch Hearts  0mJUxFpEI1eAOIIfnNoZ4G
# 13                                           In Times  1j8L336Q0X3SrJ3n8RGlHP
# 3                                      The Black Halo  44mommx98x2Dh3Ud9fdbym
# 8                              Iv: One with the Storm  1vSnkjrWUTfW4qYpvrUcQK
# 48                                       The Reticent  07PFzxEUNcMIwghKcrFGgF
# 4                             Ashes Against The Grain  73vyulFUPAla99D1wUtMQo
# 74                       April Rain (Special Edition)  62UFmoyvhEqx8GobjdUUry
# 81                             Iv: One with the Storm  3vBbCLBmaeVO1n7Ac8ZfNW
# 12                                The Living Infinite  1qlWSEuAIbceV0E5wgiPsL
# 71                                         Mind Games  4yqCklkReHaU5Qv4D4yNfI
# 24                      Darkness Leaves Nowhere to Go  6YLWkUzdBzCtXIGngc1ROj
# 87                                    Mortuus Machina  6GxHsAEPjTR9zyI0rV4LAl
# 20                                     The Poison Red  0ulKrOPVE3vyyEmm6TjmzL
# 44                                          Overworld  7du6GN7VCH6brmrjPWtqAr
# 75  Spirit in Black, Chapter Four (The Ultimate Me...  35U9ih6C8Sh28MM1ncqSuD
# 26                             Welcome To Ember Falls  6Zv775Y7YWOeG7GPhqlTM7
# 42                            Proponent for Sentience  1eORFrFz6HEwXiSVLj6EdJ
# 67                                       Omega Arcane  7ujADXhoyUUC0EDloRPgO8
# 63                                    For We Are Many  47fPXkWBYmYLcRCGrXgoYq
# 89                                            Genexus  1Ap7Pcv488cgz1AcZd5K6M
# 16                                              ZēTēS  5HRaRTQK1LBuB6CvPXF7ca
# 52                                   New Age Warriors  28ZKhsuoFoHgD9MBPAu7SO
# 64                                            Clayman  0tUy26BSKHj18TOrduBQeY
# 47                                       Quintessence  7tU55dZGSYI8GWAZhGYS5v
# 96                                          Emergence  3Op2bVsGwXrHxWs7XhR5bX
# 45                  End of an Empire (Deluxe Edition)  3tpuLPMe3FDNaasiAjF9pP
# 90                                    Coverfield - EP  41gGeMdJZl25OeoH3mQmbT
# 6                                       Damage Theory  7dpf2YZV9ROzGDtOCBJ75S
# 35                                     Drugstore Hell  0lO5KF6jc6XmRGa24iWZwf
# 28                                       Darkest Hour  7rPmNrPoUTiVjHN76n09Xa
# 37                                At War with Reality  19JwdNrMXnm2pVepX3KvfO
# 55                          Fragments Of D-Generation  094NGfQ6CvvN7uM0aC8tAi
# 9   Yomi yori kiko yu, kokoku no deung To homura n...  427cGM9lZf7y9WndXPDjf0
# 84                                        Exit Wounds  4ACqgbwaJyCMnToAcpD8wg
# 92                           Speed of Light (EP 2012)  4kbiv88z6heAS5LrrrPGiT
# 49                                       Illusion Now  0iZOviuGDLFc8vSrB4RI2T
# 27                                        Raven Kings  1zKmJBq5Ks6w9r4S9ML8Ae
# 86                                           Overcome  0XT70Wk9pP8JZkmJhfntuL
# 95                                  Forbidden Empathy  1dxwM2AlOPk0SCCGkuze1P
# 53                                Silence in the Snow  0ncHMpFGT96pis5pi4iJDm
# 61    Holiday At Lake Bodom, 15 Years of Wasted Youth  0GdvuRCPThuv4SYVaiw8ca
# 69                              The Vengeance Paradox  33HBf1US9fU6QAEINy9JRY
# 77                                            Clayman  0JBQnLKfLXmlkquabLtAgd
# 31                                           Xanthium  3tAX0Ok5tv1mReOcHEJLz5
# 66                         This War Will Last Forever  2MwLIkpvYxs0JwxNi3XP9t
# 72                                Point Zero Solution  62wSqpOnZHGVo2KZa7ihMO
# 7                                           Deadlight  70uBwhlKqPLWDPu49q9Rut
# 80                                        Persistence  0NEttDVwSNkl0m1HHadCqp
# 88                            Thank You for the Demon  2PbVdIOJxI9ZhiPSjfmze2
# 25                                              Agony  71lK2GJzwUVThQuOGKTHSE
# 36                                     From The North  3DMGwRrX0okkzr1RCoB36W
# 10                       Celldweller (Deluxe Edition)  7pypsyGCvT5yUKXuUuXc3Z
# 94                                         Progenitor  4jNnkZB2yzayqJM5knDXmE
# 93                                 The Fall of Hearts  4AHe46XPJyR6wt4jngb75M
# 43                                        Portal of I  2TYPyMen3VrXo4bljRLQvo
# 59                      Tales From The Thousand Lakes  5dnWuNRDarJhJEFabsbg8u

# %%
# top 75% of original playlist is above this score
cutoff = dict(df['scores'].describe())['75%']

# combine original playlist with top reccomendations
frames = [df, rec_df.loc[rec_df['scores'] >= cutoff]]
pull_list = pd.concat(frames, ignore_index = True)
pull_list = pull_list.drop_duplicates(subset = 'track_id')
len(pull_list)
# Out:
# 91

# %%
pull_list
# Out:
#                   track_id               artist_id  \
# 0   7LkxDAm3CxOMSFDZcRx0kI  5EHvXKnNz78jkAVgTQLQ5O
# 1   23pLHGVFWELvxIiw0CQMaX  1xUhNgw4eJDZfvumIpcz1B
# 2   2dzCUvvliKLw9dj84IRlAg  1xUhNgw4eJDZfvumIpcz1B
# 3   4ueVppRcLrdLdL7sQTHhWb  4EvbQBS99RXzFGGimAS3i9
# 4   4Lgj2JWNhM5DTWAMhz34AS  2UOVgpgiNTC6KK0vSC77aD
# 5   33Tw7bBpn08xmigGaruVhL  6e8ISIsI7UQZPyEorefAhK
# 6   0wD8PBXXq3cDndyhu0SX9D  0iem9JStyv56PV2X7avZbo
# 7   3kaEzsEQ6JweUJwzjpCCce  4XJZ7zUJzQuayqyAVJowKX
# 8   3HnwTO5lY1TeWYzFcnM4Eh  57ylwQTnFnIhJh4nu4rxCs
# 9   6xPwcnwKGZfeLxCHMtbVhu  3uIgLG971oRM5fe6v8lvQS
# 10  6gOPxIln3rnSiBiGEApiak  2CWWgbxApjbyByxBBCvGTm
# 11  5S3OzvGuRpK7HrjQqKreCd  6dhqzgrbFggOBns03STnU3
# 12  34ss3R4VC7PO7c0xJnK7ZZ  6dhqzgrbFggOBns03STnU3
# 13  294Qb8EGfUjmZhaxROiLiV  0ybFZ2Ab08V8hueghSXm6E
# 14  0QEHU9mrMu45022YLSi01o  2PQVMx0BpRQhzMWLa7X0T6
# 15  03hUjXfWyepgPxWfBsrG0r  5jQPKWBobu6cJwGSbbqgCk
# 16  7jeQrf3YHkMBftGajj8Wqm  5jQPKWBobu6cJwGSbbqgCk
# 17  2v4gF2JIQXqdbVpZiyvDHj  7wqP36o9lqWteOCxBnXlwx
# 18  5n2wvt1G5ywxT1y6LGuDJB  57ylwQTnFnIhJh4nu4rxCs
# 19  6wdlDku4keVEE6pVFvPdCa  1LRaJctZMltNoojcEj5OPE
# 20  3z7jm3G3rdp05oTzYWkHNi  2CWWgbxApjbyByxBBCvGTm
# 21  1FQtNCA2nYXEeZ41Z4XyH7  3uIgLG971oRM5fe6v8lvQS
# 22  2NM3ydi7uBrhux2mYK2lrI  0iem9JStyv56PV2X7avZbo
# 23  2OhnDHT5LGG0ZAnjFEBsbg  5EHvXKnNz78jkAVgTQLQ5O
# 24  6OGkZoqso1wbIy5O6cV56N  0ybFZ2Ab08V8hueghSXm6E
# 25  4UiUd7ClIzWK0r3qkswGc6  1LRaJctZMltNoojcEj5OPE
# 26  5Dr8bgZuyfI5Nki04oYz2x  4EvbQBS99RXzFGGimAS3i9
# 27  3NMLi31rokgkE7YilcM0B9  2PQVMx0BpRQhzMWLa7X0T6
# 28  53ZwCHcVQ5hOk4wFNDgmzn  37394IP6uhnjIpsawpMu4l
# 29  3JDbNcCA0sqls4hQCKY8ph  5rKi8nP7CfFcbjz3DpA9Yx
# 30  3f4VN0IHlMyMRVtnbiVqm3  5ctFffJBdJe8PZL7W7NeML
# 31  2nUy0ifVE7UwtOK4rugFsP  37394IP6uhnjIpsawpMu4l
# 32  7x9gPXIuiG4K45JGR1Zqyq  6e8ISIsI7UQZPyEorefAhK
# 33  4u4qXxJXwqUQfrvr8FXGHj  7wqP36o9lqWteOCxBnXlwx
# 34  4etOTfwzJCDQVUbLJqg2kF  5ctFffJBdJe8PZL7W7NeML
# 35  42lC6bnDdAjRqZtsFe1tmg  37394IP6uhnjIpsawpMu4l
# 36  7ddRAfvlc1UG3HZ8Fi9Hku  4XJZ7zUJzQuayqyAVJowKX
# 37  0yRRVy4pI3Oa1qqqUpuGME  5EHvXKnNz78jkAVgTQLQ5O
# 38  6GxHsAEPjTR9zyI0rV4LAl  0NZfW1mCAUJQeRqBuBdRuj
# 39  5UqR2S9N3RTYNmpnpEYCwj  0NZfW1mCAUJQeRqBuBdRuj
# 40  3sizVMerlajPegOZWbMKwZ  5ctFffJBdJe8PZL7W7NeML
# 41  1i1X96hevCrjhapdlIkSy4  2UOVgpgiNTC6KK0vSC77aD
# 42  49Cc4uBdMIPPDDjmcn8DLb  4EvbQBS99RXzFGGimAS3i9
# 43  22FQS8s7RyroEWsidsGnAg  5rKi8nP7CfFcbjz3DpA9Yx
# 44  0ajbDpi2CQ9sl2uBMUSNpj  5rKi8nP7CfFcbjz3DpA9Yx
# 45  5oKvrJSRVxwAvnWERfZ0aE  6e8ISIsI7UQZPyEorefAhK
# 46  094NGfQ6CvvN7uM0aC8tAi  0iem9JStyv56PV2X7avZbo
# 47  7kPVWNVbEUsguLRWRk8W33  57ylwQTnFnIhJh4nu4rxCs
# 48  5FSlmn3QXiIbc3i1OHJLDa  2CWWgbxApjbyByxBBCvGTm
# 49  4bOX3KfGgQE1GkxxJ3OUtI  3uIgLG971oRM5fe6v8lvQS
# 50  0cgz0Fa7bivUEwqI5Srj1P  0ybFZ2Ab08V8hueghSXm6E
# 51  5ceYVTBWOXrxuwzkrkS4ob  5jQPKWBobu6cJwGSbbqgCk
# 52  63iczcpxd8c5aV8Yqsn8MD  52xuvlUvnxqH0xzxGPKXSu
# 53  4YKY4vsi5tJKK2KsNY4zO5  52xuvlUvnxqH0xzxGPKXSu
# 54  3tmXnVTDKLsaiuXuSv6AwN  52xuvlUvnxqH0xzxGPKXSu
# 55  12pdTPMSl9W97GbWJZZEqY  4wxyib7wQwVxwKNFBmOhAw
# 56  5tTV0Z32WckGngHWSbghTn  2UOVgpgiNTC6KK0vSC77aD
# 57  7fX3rcplzuNOF7YPsUTQTE  3mBFvlqINbTNsRB6htlJEY
# 58  37VeO4NGjwGaHMlfOK7eFW  3mBFvlqINbTNsRB6htlJEY
# 59  5i30fpdkqG28N9D2wThwdP  71RNihAnOuMIGlq9zQiDXx
# 60  1Hq0JyflW9EE2HR7rU6jOJ  1k0jnWb55QS6FjTU9LzMhi
# 61  1xFrfYd7PHXTAriPTOfxL8  2YPVtFn6SsYNntkmrdDpGF
# 62  09PDLrMCcoClfbnXrCBmMy  1k0jnWb55QS6FjTU9LzMhi
# 63  2XD4NowUR2fQHNTF2FO1T5  384RPjoLeqSOcy5qS9oQgX
# 64  4NFa3dMT0FhJ4yJkCdMPwz  0NTSMFFapnyZfvmCwzcYPd
# 65  4xGL0QDJxlGhLKXmHso1Ie  0NTSMFFapnyZfvmCwzcYPd
# 66  4riKzzeTonEgPN9OCCvMqQ  7gTbq5nTZGQIUgjEGXQpOS
# 67  2IFNfSqJqygGPE38aJn5sh  5NIvyOvy39ljx9w71rnCS1
# 68  2ZYsMOE4QpWICp8LQR6iku  5NIvyOvy39ljx9w71rnCS1
# 69  10iJFxrM8Pbhtqw7TGTZdi  7wqP36o9lqWteOCxBnXlwx
# 70  2lN6G35gsXkA3xzPYqmis5  7MqnCTCAX6SsIYYdJCQj9B
# 71  1NAYWRWQhEglu5MvcCjsJo  1GfzxrTlFX1DmRSVqMUvaD
# 72  17mh54ovFWLJQKgFnpRnSP  2PQVMx0BpRQhzMWLa7X0T6
# 73  6MM6J46UQqXE4nz37UOGWL  1xUhNgw4eJDZfvumIpcz1B
# 74  372diRsJu7fxKmVuuH02kC  4wxyib7wQwVxwKNFBmOhAw
# 75  4cOVDjeBdpQiU4Qolf9JXp  5MlHrCJ7ub9tJSG8Zd62R9
# 76  23LWwPj1HF3MeSDF7GGhPG  4S0foX2r0RlC12KBW8u73D
# 78  4BFsNwlAP8AxLX4BOsTFlq  0er4R5wQIjww94ziq9YcBf
# 79  7qQeldOEJZ5JLSN3L8VA9M  553eIV3aSzE17cxgVVG7o6
# 80  1suh3dQIhaJiHger91tDQ0  7wqP36o9lqWteOCxBnXlwx
# 81  5mu5oz5S8DkWKEjzYs0Udy  41nB823nb3wxEI25UeGHqG
# 82  5EoXDEYfLTRAvaWX25tvDw  7wqP36o9lqWteOCxBnXlwx
# 83  0wZPKoGk8ddgmgqVUXaWBc  3xdRLrB6lz0WEh66MUt98U
# 84  6T37SarFYXVJ1Ax5cT9g8e  3rdFnKhyWhTivuBFSH4YT3
# 85  7E23KVVacUy7IXPwF60iZG  18RXUrxy1BYOOvrW0XuFBg
# 86  4sHSGl11LQbHVynHu3p6JX  7ig8pUnno95YNA9MclOveH
# 87  7wblhWFRa2J9isIoOAhFkk  3xdRLrB6lz0WEh66MUt98U
# 88  0z76WoplujZmszn7d6KGyn  5NIvyOvy39ljx9w71rnCS1
# 89  0qwHMBslXUZo7ePfVYnU5X  7FYqu76teK16FSlw4ZYFhW
# 90  02jmSLjpElhxW6w0waFQtw  52xuvlUvnxqH0xzxGPKXSu
# 91  52ygtenQsKPjJLvp63XSsj  5toPnT62e4myQ3N21WfWtS
#
#                                                  name  \
# 0                                    The Lesser Faith
# 1                                         Hatebreeder
# 2                                    Towards Dead End
# 3                                             Eternal
# 4                                               Sampo
# 5                                  In Death's Embrace
# 6                                Nihilistic Overdrive
# 7                                    Beauty of Malice
# 8                                          Ever Dying
# 9                                    Devoid Of Caring
# 10                                          New Night
# 11                                      Surge Of Pity
# 12                                          Reconcile
# 13                                              Bleak
# 14         Ghost Prototype I - Measurement of Thought
# 15                           May Today Become the Day
# 16                                    End of the Road
# 17                               Petrichor by Sulphur
# 18                   Square Nothing - 2020 Remastered
# 19                                           With You
# 20                              Deliberation - Studio
# 21                          Where The Last Wave Broke
# 22                                  Celestial Furnace
# 23                               Monochromatic Stains
# 24                                      Heir Apparent
# 25                                             Voices
# 26                                        Metropolice
# 27                                      Timewave Zero
# 28                                 This Is Absolution
# 29                                  Grown Of Creation
# 30                                              Sugar
# 31                               The End of Heartache
# 32                     Kings of the Carnival Creation
# 33                                          Stålfågel
# 34                                        In Aeternum
# 35                                 The Arms of Sorrow
# 36                                       Suicide Code
# 37                                     Lost to Apathy
# 38                                Fractured Archetype
# 39                                Sum Of The Universe
# 40                   Minotaur (The Wrath of Poseidon)
# 41                                              Elegy
# 42                                   Crimson Symphony
# 43                                  Martyr To Science
# 44                                     Losers' Ballet
# 45                                    Hybrid Stigmata
# 46                                         Red Clouds
# 47                                  Reflect The Storm
# 48                                        I Transpire
# 49                                 Through The Shadow
# 50                         Reverie / Harlequin Forest
# 51                             Killing Me Killing You
# 52                                  New World Shadows
# 53                                   The Second Flame
# 54                                   Sons Of Thoughts
# 55                                   Mind as Universe
# 56                                          The Smoke
# 57                        Supreme Pain For The Tyrant
# 58                                        Broken Jade
# 59                       Sleep Well the Darkest Night
# 60                              Parasites Of Paradise
# 61                                       Heroes To Us
# 62                                The Harmony Remains
# 63                               Enhance My Nightmare
# 64                                            Nemesis
# 65                                  Summer Dying Fast
# 66  The Haunting (Somewhere in Time) [feat. Simone...
# 67                            Tsunami and Submergence
# 68    Gray Matter Mechanics - Apassionata Ex Machinea
# 69                                        Shadowchild
# 70                     Self vs Self (feat. In Flames)
# 71                                   Rikki Tikki Tavi
# 72                Deviate from the Form - Bonus Track
# 73                        Red Light In My Eyes, Pt. 2
# 74                            Returning to the Source
# 75                                        Unbreakable
# 76                                    My Allied Ocean
# 78                            Strenght from My Wounds
# 79                                          In Sorrow
# 80                                   Death in General
# 81                                             Dynamo
# 82                               The Nurturing Glance
# 83                               Ascend to the Throne
# 84                                    Legion Of Beast
# 85                                          Afterlife
# 86                                    Midnight Runner
# 87                                   Decoding Reality
# 88                              Preaching the Machine
# 89                                       Frozen Angel
# 90                                  Blade Reflections
# 91                                     Eye for an Eye
#
#                                           album                   artist  \
# 0                                       Fiction        Dark Tranquillity
# 1                                   Hatebreeder        Children Of Bodom
# 2                                   Hatebreeder        Children Of Bodom
# 3                                       Epsilon        Blood Stain Child
# 4                                     Skyforger                 Amorphis
# 5                  Enthrone Darkness Triumphant             Dimmu Borgir
# 6                Mind Tricks (Extended Version)         Disarmonia Mundi
# 7                             Engraved in Black                Graveworm
# 8                                  Subterranean                In Flames
# 9                       Above The Weeping World                Insomnium
# 10                         Night Is the New Day                Katatonia
# 11                        A New Disease Is Born                Nightrage
# 12                        A New Disease Is Born                Nightrage
# 13                              Blackwater Park                    Opeth
# 14                         Holographic Universe            Scar Symmetry
# 15                            The Funeral Album                Sentenced
# 16                            The Funeral Album                Sentenced
# 17                            The Ride Majestic                 Soilwork
# 18           Clayman (20th Anniversary Edition)                In Flames
# 19                                       Masked          Machinemade God
# 20                      The Great Cold Distance                Katatonia
# 21                              Across The Dark                Insomnium
# 22               Mind Tricks (Extended Version)         Disarmonia Mundi
# 23                                  Damage Done        Dark Tranquillity
# 24                  Watershed (Special Edition)                    Opeth
# 25                                       Masked          Machinemade God
# 26                                       Mozaiq        Blood Stain Child
# 27                         Holographic Universe            Scar Symmetry
# 28                             As Daylight Dies        Killswitch Engage
# 29                                       Wolves                 Deadlock
# 30                                       Veleno      Fleshgod Apocalypse
# 31       The End of Heartache (Special Edition)        Killswitch Engage
# 32            Puritanical Euphoric Misanthropia             Dimmu Borgir
# 33                                     Feverish                 Soilwork
# 34                                         King      Fleshgod Apocalypse
# 35           As Daylight Dies (Special Edition)        Killswitch Engage
# 36                            Collateral Defect                Graveworm
# 37                                    Character        Dark Tranquillity
# 38                              Mortuus Machina                Universum
# 39                              Mortuus Machina                Universum
# 40                                    Labyrinth      Fleshgod Apocalypse
# 41                                        Elegy                 Amorphis
# 42                     Silence of Northern Hell        Blood Stain Child
# 43                                    Manifesto                 Deadlock
# 44                                       Wolves                 Deadlock
# 45            Puritanical Euphoric Misanthropia             Dimmu Borgir
# 46                    Fragments Of D-Generation         Disarmonia Mundi
# 47                                 Come Clarity                In Flames
# 48    Last Fair Deal Gone Down (Deluxe Edition)                Katatonia
# 49                               One For Sorrow                Insomnium
# 50                               Ghost Reveries                    Opeth
# 51                       Killing Me Killing You                Sentenced
# 52                            New World Shadows          Omnium Gatherum
# 53                                 The Redshift          Omnium Gatherum
# 54  Spirits And August Lights / Steal The Light          Omnium Gatherum
# 55                          Spiritual Migration                Persefone
# 56                                      Eclipse                 Amorphis
# 57                                       Bù-Tik                 CHTHONIC
# 58                                Takasago Army                 CHTHONIC
# 59                                Ashes of Fate           Logical Terror
# 60                                   The Unborn      Mors Principium Est
# 61                                    Swampsong                   Kalmah
# 62                                   The Unborn      Mors Principium Est
# 63                                    Eden Fire          Sonic Syndicate
# 64                                 Nymphetamine          Cradle Of Filth
# 65                     Bitter Suites to Succubi          Cradle Of Filth
# 66                               The Black Halo                  Kamelot
# 67                                    Apoptosis                Allegaeon
# 68                      Proponent for Sentience                Allegaeon
# 69             A Predator's Portrait (Reloaded)                 Soilwork
# 70                                    Immersion                 Pendulum
# 71                             Arrows & Anchors          Fair To Midland
# 72                         Pitch Black Progress            Scar Symmetry
# 73                               Something Wild        Children Of Bodom
# 74                          Spiritual Migration                Persefone
# 75                                  Unbreakable        My Dear Addiction
# 76                             The Storm Within                 Evergrey
# 78                               Into the Abyss                   Lahmia
# 79                            XI Reasons to See                Destinity
# 80                            The Ride Majestic                 Soilwork
# 81                                          SLK                  Stam1na
# 82                                 Verkligheten                 Soilwork
# 83                             Defying the Gods             Rise to Fall
# 84                                 Saivon lapsi  Eternal Tears Of Sorrow
# 85                               Heroes in Time                 Metalite
# 86                              Midnight Runner                 Mustasch
# 87                             Defying the Gods             Rise to Fall
# 88                                      2008 EP                Allegaeon
# 89                                            N                  Norther
# 90                            Blade Reflections          Omnium Gatherum
# 91                                       Origin           The Hypothesis
#
#    release_date     length  popularity  key  mode  ...  danceability  energy  \
# 0    2007-09-26   4.630433        0.35    7     1  ...        0.4110   0.965
# 1    1999-05-04   4.319550        0.44    7     0  ...        0.4170   0.976
# 2    1999-05-04   4.901100        0.39    2     0  ...        0.1880   0.949
# 3    2011-06-30   4.498000        0.27    1     1  ...        0.5080   0.977
# 4    2009-05-29   6.147333        0.16    7     1  ...        0.1590   0.763
# 5    1997-05-30   5.702667        0.41    5     1  ...        0.0975   0.897
# 6          2006   4.858000        0.30   11     0  ...        0.3920   0.985
# 7    2003-06-30   5.411100        0.13    4     1  ...        0.4310   0.977
# 8    1995-06-15   4.388567        0.19    7     0  ...        0.3420   0.830
# 9    2006-08-09   5.671333        0.24    5     1  ...        0.4010   0.978
# 10   2009-01-01   4.430883        0.24    0     0  ...        0.2250   0.711
# 11   2007-03-12   4.206217        0.10   10     0  ...        0.4320   0.995
# 12   2007-03-12   4.420667        0.18    9     0  ...        0.1880   0.989
# 13   2001-02-27   9.265550        0.38    9     0  ...        0.2510   0.866
# 14   2008-06-20   4.594433        0.44   11     0  ...        0.4610   0.975
# 15   2005-07-13   4.009100        0.31    2     0  ...        0.4790   0.936
# 16   2005-07-13   5.005767        0.39    8     1  ...        0.2560   0.838
# 17   2015-08-28   5.185717        0.27    0     1  ...        0.2850   0.967
# 18   2020-08-28   3.923217        0.33    8     1  ...        0.5100   0.929
# 19   2007-09-04   3.727567        0.14    5     0  ...        0.4370   0.925
# 20   2006-03-13   3.993100        0.40    5     1  ...        0.5330   0.740
# 21   2009-09-07   5.032667        0.31    7     1  ...        0.4640   0.977
# 22         2006   3.800883        0.43   11     0  ...        0.4140   0.991
# 23   2002-07-13   3.632667        0.33    6     1  ...        0.3900   0.923
# 24   2008-06-03   8.840000        0.42   11     0  ...        0.2520   0.961
# 25   2007-09-04   4.763183        0.18   10     0  ...        0.4880   0.954
# 26         2007   3.987550        0.38    8     1  ...        0.4180   0.934
# 27   2008-06-20   5.219333        0.37    7     1  ...        0.2730   0.954
# 28   2006-01-21   3.572667        0.36    2     0  ...        0.4390   0.989
# 29   2007-04-16   4.857767        0.11    0     0  ...        0.3030   0.988
# 30   2019-05-24   4.287100        0.40    4     0  ...        0.2060   0.989
# 31   2004-05-03   4.968433        0.63    0     0  ...        0.4690   0.976
# 32   2001-03-12   7.808000        0.44    6     0  ...        0.2210   0.965
# 33   2019-10-25   4.493350        0.22   11     0  ...        0.5570   0.972
# 34   2016-02-05   5.427333        0.42   11     0  ...        0.2560   0.984
# 35   2006-01-21   3.735333        0.56    5     0  ...        0.4990   0.963
# 36   2007-05-25   3.891800        0.17   11     0  ...        0.3740   0.981
# 37   2005-07-13   4.645333        0.38    9     1  ...        0.3400   0.965
# 38   2010-12-16   4.366667        0.26    9     0  ...        0.3390   0.949
# 39   2010-12-16   4.427333        0.19    7     1  ...        0.4480   0.959
# 40   2013-08-16   5.170217        0.38   11     1  ...        0.2850   0.990
# 41         1996   7.352667        0.22    3     1  ...        0.3000   0.685
# 42         2002   4.778883        0.09    9     0  ...        0.3550   0.957
# 43         2008   5.231550        0.09    8     1  ...        0.4470   0.995
# 44   2007-04-16   6.661333        0.13   10     0  ...        0.2370   0.935
# 45   2001-03-12   6.962500        0.39    0     1  ...        0.1570   0.940
# 46         2004   5.343333        0.23   11     0  ...        0.4150   0.971
# 47   2006-02-03   4.275317        0.35    8     1  ...        0.4190   0.974
# 48         2001   5.941333        0.18    1     0  ...        0.1890   0.824
# 49   2012-09-26   4.543333        0.40    5     1  ...        0.4160   0.972
# 50   2005-08-30  11.657767        0.46    9     0  ...        0.3020   0.785
# 51   1999-05-13   4.252667        0.48    0     0  ...        0.5450   0.847
# 52   2011-03-01   6.016000        0.18    1     0  ...        0.4600   0.957
# 53   2008-09-22   4.403767        0.17    2     1  ...        0.4120   0.962
# 54   2004-10-25   5.323333        0.05    1     0  ...        0.2630   0.958
# 55   2013-03-29   4.688000        0.29    2     1  ...        0.1780   0.987
# 56   2006-02-17   3.648433        0.30    0     0  ...        0.3620   0.798
# 57   2013-01-01   4.764433        0.13    7     1  ...        0.4760   0.986
# 58   2011-01-01   5.714217        0.21    7     1  ...        0.4840   0.980
# 59   2016-05-06   4.819900        0.03   11     0  ...        0.4360   0.894
# 60         2005   4.324217        0.00   11     1  ...        0.3190   0.756
# 61   2003-05-23   4.909767        0.47    2     0  ...        0.3750   0.948
# 62         2005   4.856883        0.00    4     0  ...        0.4130   0.967
# 63   2005-08-24   5.168000        0.26    2     0  ...        0.4680   0.945
# 64   2004-09-20   7.292433        0.35    0     0  ...        0.2340   0.986
# 65         2001   5.355767        0.29    2     0  ...        0.2050   0.950
# 66   2005-03-15   5.672883        0.50    1     0  ...        0.2810   0.841
# 67   2019-04-19   6.437250        0.23    4     1  ...        0.2960   0.990
# 68   2016-09-23   8.306217        0.33    7     0  ...        0.5220   0.913
# 69   2008-09-05   4.646217        0.14    8     0  ...        0.2000   0.964
# 70   2010-05-21   4.761767        0.57   10     0  ...        0.4380   0.989
# 71   2011-07-12   3.422667        0.37    8     1  ...        0.4710   0.875
# 72   2006-04-21   5.443467        0.27    3     0  ...        0.5190   0.986
# 73   1997-02-26   3.836667        0.31    1     0  ...        0.1250   0.988
# 74   2013-03-29   9.101333        0.21    7     0  ...        0.2060   0.975
# 75   2013-09-27   2.951833        0.29    9     0  ...        0.4640   0.971
# 76   2016-09-09   4.110000        0.39    1     1  ...        0.4640   0.985
# 78   2012-05-28   4.218217        0.19    1     0  ...        0.5360   0.941
# 79   2010-02-22   4.653550        0.07   11     0  ...        0.5020   0.981
# 80   2015-08-28   4.995100        0.30    9     0  ...        0.3940   0.981
# 81   2014-02-07   3.784667        0.36    8     1  ...        0.4900   0.969
# 82   2019-01-11   5.412467        0.37    4     1  ...        0.4510   0.971
# 83   2012-04-09   3.583333        0.32    1     1  ...        0.4410   0.980
# 84   2013-01-29   4.053100        0.15    2     1  ...        0.4180   0.968
# 85   2017-10-27   4.160000        0.39   11     0  ...        0.4310   0.968
# 86   2016-10-03   4.165550        0.29    0     1  ...        0.4940   0.893
# 87   2012-04-09   4.046217        0.14    6     1  ...        0.4570   0.974
# 88   2008-01-01   4.706000        0.12    4     0  ...        0.4750   0.984
# 89   2008-07-13   4.113767        0.44    2     1  ...        0.4220   0.954
# 90   2017-10-13   4.960033        0.24    6     0  ...        0.4570   0.982
# 91   2016-05-05   4.775000        0.12    1     1  ...        0.4320   0.973
#
#     valence  instrumentalness  liveness  loudness  speechiness    tempo  \
# 0    0.4220          0.216000    0.0630    -4.503       0.0565  159.993
# 1    0.6380          0.837000    0.3870    -3.196       0.0507  111.709
# 2    0.5380          0.839000    0.3200    -2.490       0.0599  108.075
# 3    0.3050          0.014500    0.1620    -4.582       0.0709  104.993
# 4    0.2690          0.025700    0.8120    -4.462       0.0390  175.869
# 5    0.1910          0.870000    0.1600    -5.352       0.0669   89.358
# 6    0.2390          0.564000    0.1990    -2.937       0.0720   95.003
# 7    0.2320          0.672000    0.2500    -2.959       0.0788  129.977
# 8    0.1590          0.879000    0.3030    -7.971       0.0584  105.001
# 9    0.1080          0.947000    0.2410    -3.235       0.0777   94.975
# 10   0.2020          0.002940    0.3660    -6.508       0.0306  179.824
# 11   0.3990          0.295000    0.1180    -3.098       0.0800  140.043
# 12   0.1820          0.071700    0.6380    -3.058       0.1600  101.309
# 13   0.3000          0.657000    0.6000    -4.899       0.0737   94.980
# 14   0.5970          0.002510    0.0997    -2.685       0.0738   90.001
# 15   0.4330          0.000051    0.1280    -5.464       0.0554   89.988
# 16   0.3110          0.186000    0.1240    -6.683       0.0400  108.082
# 17   0.4720          0.000000    0.1150    -4.086       0.0929  127.762
# 18   0.5180          0.751000    0.0688    -5.192       0.0367  140.104
# 19   0.5020          0.059100    0.1460    -4.454       0.0746  180.111
# 20   0.4240          0.019300    0.3630    -7.205       0.0334   89.986
# 21   0.1390          0.116000    0.1310    -4.299       0.0678  117.488
# 22   0.3050          0.019300    0.1510    -2.360       0.0615   94.994
# 23   0.4650          0.265000    0.0524    -6.463       0.1030   87.564
# 24   0.0694          0.858000    0.1860    -4.937       0.0902  144.532
# 25   0.4170          0.007840    0.1060    -3.986       0.0830   95.009
# 26   0.1370          0.020800    0.0574    -4.294       0.0665  120.021
# 27   0.5350          0.001490    0.3520    -3.240       0.0826  199.915
# 28   0.2330          0.003600    0.3620    -2.266       0.0530  158.004
# 29   0.1330          0.712000    0.1040    -3.769       0.1140  118.092
# 30   0.0345          0.107000    0.2630    -6.858       0.2470   95.054
# 31   0.2220          0.217000    0.0636    -3.569       0.1110  124.001
# 32   0.1260          0.120000    0.0655    -2.872       0.1000  116.625
# 33   0.0459          0.237000    0.1120    -4.380       0.1360  105.037
# 34   0.1100          0.032700    0.8120    -4.664       0.1520  112.509
# 35   0.1600          0.000507    0.6080    -2.729       0.0578  123.981
# 36   0.1590          0.184000    0.1480    -1.409       0.0764  176.054
# 37   0.2120          0.020600    0.0608    -4.444       0.0691  107.753
# 38   0.3250          0.744000    0.5790    -4.339       0.0523  165.953
# 39   0.2640          0.447000    0.0535    -4.887       0.0720  139.964
# 40   0.0690          0.005280    0.7910    -2.680       0.1580  119.425
# 41   0.3040          0.028300    0.2800    -6.431       0.0306  135.746
# 42   0.3420          0.142000    0.0450    -3.684       0.0542  104.981
# 43   0.0668          0.213000    0.2840    -1.649       0.1910  129.963
# 44   0.0385          0.912000    0.1320    -4.964       0.1230  109.981
# 45   0.2310          0.371000    0.2950    -2.662       0.0588  152.626
# 46   0.2460          0.940000    0.1470    -1.673       0.0676   87.979
# 47   0.0747          0.130000    0.3100    -3.903       0.1080  104.951
# 48   0.2220          0.792000    0.0794    -5.897       0.0399  112.245
# 49   0.1570          0.000041    0.3140    -4.966       0.1120  122.487
# 50   0.2560          0.009220    0.3310    -6.328       0.0439  146.460
# 51   0.1640          0.000025    0.1900    -4.317       0.0351  114.997
# 52   0.1320          0.678000    0.0565    -5.781       0.0587  122.058
# 53   0.2010          0.001450    0.1140    -4.299       0.0788  163.967
# 54   0.1520          0.281000    0.1790    -3.286       0.0530  125.019
# 55   0.1510          0.149000    0.1840    -4.630       0.4060  184.785
# 56   0.4950          0.340000    0.1040    -5.159       0.0448  103.961
# 57   0.3130          0.000042    0.1280    -3.673       0.1390  159.967
# 58   0.1960          0.103000    0.1080    -2.726       0.1220  112.454
# 59   0.2850          0.003780    0.3030    -7.360       0.1150  151.741
# 60   0.3160          0.218000    0.1050    -5.593       0.0799  194.947
# 61   0.1400          0.836000    0.3060    -5.049       0.0740   99.918
# 62   0.1310          0.130000    0.1590    -5.346       0.1210  122.458
# 63   0.1340          0.558000    0.1160    -3.704       0.1100  105.014
# 64   0.1250          0.019700    0.2460    -3.397       0.1120   95.708
# 65   0.0635          0.100000    0.4320    -5.769       0.1080   97.761
# 66   0.2860          0.000139    0.2620    -7.232       0.0670  120.016
# 67   0.0965          0.717000    0.0618    -3.810       0.1450  113.442
# 68   0.1260          0.430000    0.1200    -5.994       0.0664  144.983
# 69   0.3020          0.824000    0.2310    -4.730       0.1280  136.979
# 70   0.3320          0.001980    0.9410    -2.354       0.0959  174.012
# 71   0.4300          0.000060    0.1300    -4.989       0.0350  104.938
# 72   0.4520          0.000328    0.3650    -4.238       0.0531  119.984
# 73   0.1820          0.098100    0.1450    -4.079       0.2040  182.619
# 74   0.1950          0.341000    0.0717    -4.635       0.1650  165.053
# 75   0.3730          0.018000    0.0788    -4.329       0.0887  100.001
# 76   0.2360          0.000079    0.1000    -5.389       0.1390   89.984
# 78   0.2940          0.004680    0.2460    -4.028       0.0723   95.002
# 79   0.2520          0.187000    0.1170    -3.402       0.1250  126.050
# 80   0.0953          0.000019    0.0748    -4.156       0.1290  134.902
# 81   0.1960          0.009390    0.0805    -2.794       0.1150  142.049
# 82   0.2840          0.605000    0.3050    -3.106       0.0750  142.020
# 83   0.3430          0.029800    0.0987    -5.381       0.0688  114.005
# 84   0.1890          0.339000    0.0751    -6.035       0.1380  125.015
# 85   0.4390          0.054900    0.1170    -4.969       0.0773   95.005
# 86   0.3350          0.152000    0.1490    -4.642       0.0842  138.065
# 87   0.4550          0.058600    0.2460    -5.319       0.0793  117.976
# 88   0.0840          0.000269    0.2840    -4.174       0.1370  140.036
# 89   0.2710          0.000089    0.1740    -4.018       0.0653   87.552
# 90   0.3460          0.202000    0.0617    -5.093       0.1000  132.497
# 91   0.4270          0.077400    0.1570    -3.981       0.0987  144.971
#
#     time_signature    scores
# 0                4  0.137714
# 1                4  0.044909
# 2                4  0.088695
# 3                4  0.170371
# 4                3 -0.029062
# 5                4  0.099276
# 6                4  0.143037
# 7                4  0.123568
# 8                4  0.024356
# 9                4  0.104753
# 10               3 -0.039145
# 11               3  0.058195
# 12               3  0.044262
# 13               4  0.017161
# 14               4  0.094349
# 15               4  0.129405
# 16               4  0.115478
# 17               4  0.149748
# 18               4  0.084738
# 19               3  0.031050
# 20               4  0.017408
# 21               4  0.172070
# 22               4  0.121946
# 23               4  0.081865
# 24               4  0.069867
# 25               4  0.147241
# 26               4  0.133006
# 27               4  0.073999
# 28               4  0.104963
# 29               3  0.068508
# 30               4  0.045172
# 31               4  0.096924
# 32               4  0.107966
# 33               4  0.135062
# 34               3  0.024944
# 35               4  0.071175
# 36               4  0.096864
# 37               3  0.098109
# 38               4  0.076042
# 39               4  0.147419
# 40               3 -0.086155
# 41               4  0.034245
# 42               4  0.136245
# 43               4  0.058469
# 44               4  0.067172
# 45               3  0.039090
# 46               4  0.061979
# 47               4  0.108787
# 48               3  0.016480
# 49               4  0.154815
# 50               4 -0.035671
# 51               4  0.114846
# 52               4  0.122408
# 53               4  0.146438
# 54               4  0.134355
# 55               4  0.036376
# 56               4  0.081985
# 57               4  0.095750
# 58               3  0.094711
# 59               4  0.044194
# 60               4  0.021322
# 61               4  0.114281
# 62               4  0.125833
# 63               4  0.145923
# 64               4  0.123544
# 65               3  0.039839
# 66               4  0.084046
# 67               3  0.035908
# 68               4  0.017067
# 69               4  0.115251
# 70               4  0.012455
# 71               3  0.033904
# 72               4  0.133817
# 73               4  0.093413
# 74               4  0.067637
# 75               4  0.136988
# 76               4  0.124906
# 78               4  0.145093
# 79               4  0.138885
# 80               4  0.142138
# 81               4  0.134238
# 82               4  0.130112
# 83               4  0.143206
# 84               4  0.123204
# 85               4  0.145078
# 86               4  0.139749
# 87               4  0.125340
# 88               4  0.123839
# 89               4  0.140400
# 90               4  0.149192
# 91               4  0.135866
#
# [91 rows x 21 columns]

# %%
def generate_playlist(input_track, input_playlist):
    refresh()
    pickiness = 3 # number of nearest songs
    knn = NearestNeighbors(n_neighbors = pickiness + 1)
    up_next = []
    up_next_length = 24 
    working_playlist = input_playlist
    
    seed = input_track
    up_next.append(input_track)
    
    for i in range(up_next_length): 

    # find seed track nearest neighbors (currently returns 6, trimmed down to 5)
        current_id = working_playlist.loc[working_playlist['track_id'] == seed]

    # retrain every, necessary evil to ensure closest remaining neighbors are selected
        knn_fit = preprocess(working_playlist)
        knn.fit(knn_fit)

    # find n nearest neighbors (6, generally includes self as nearest)
        processed_c_id = preprocess(current_id)
        neighbors = knn.kneighbors(processed_c_id,
                                   return_distance = False)
        neighbors_list = np.concatenate(neighbors).ravel().tolist()

    # exclude current seed as a next seed option
        seed_index = working_playlist.index[working_playlist['track_id'] == seed].to_list()
        for i in range(len(neighbors_list)-1):
            if neighbors_list[i] == seed_index[0]:
                del neighbors_list[i]
            else:
                pass

    # logic to reduce to drop furthest if seed isn't a nearest neighbor to self (not common in testing)
        if len(neighbors_list) == pickiness + 1:
            neighbors_list = neighbors_list[:pickiness]
        else:
            pass

    # randomly selected new seed from neighbors
        new_seed_index = []
        new_seed_index.append(random.choice(neighbors_list))
    
    # logic to greatly reduce probability of repeating artists back to back
        seed_artist = working_playlist.iloc[seed_index,[1]].values[0][0]
        new_seed_artist = working_playlist.iloc[new_seed_index,[1]].values[0][0]
        if seed_artist == new_seed_artist:
            neighbors_list.remove(new_seed_index[0])
            new_seed_index = []
            new_seed_index.append(random.choice(neighbors_list))
        else:
            pass
    
        new_seed = working_playlist.iloc[new_seed_index,[0]]
        new_seed_id = new_seed['track_id'].tolist()
        new_seed_id = new_seed_id[0]

    # update queue with new track id
        up_next.extend(new_seed['track_id'].tolist())

    # drop old seed from available seeds. cleans up dataframe
        working_playlist = working_playlist.drop(seed_index[0], 0)
        working_playlist.reset_index(inplace = True)
        working_playlist = working_playlist.drop(working_playlist.columns[[0]], 1)

        seed = new_seed_id

    # querry input playlist to generate a df with necessary info
    compile_playlist = []
    for i in range(len(up_next)):
        track = input_playlist.loc[input_playlist['track_id'] == up_next[i]]
        track_list = track[['track_id', 'name', 'artist','album']].values.tolist()
        compile_playlist.extend(track_list)
    final_playlist = pd.DataFrame(compile_playlist, columns =['track_id', 'name', 'artist','album'])
    
    return final_playlist

# %%
input_track = '4bOX3KfGgQE1GkxxJ3OUtI'
input_playlist = pull_list

generate_playlist(input_track, input_playlist)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-116-5cce61a35214> in <module>
#       2 input_playlist = pull_list
#       3
# ----> 4 generate_playlist(input_track, input_playlist)
#
# <ipython-input-115-390dfd19337d> in generate_playlist(input_track, input_playlist)
#      16
#      17     # retrain every, necessary evil to ensure closest remaining neighbors are selected
# ---> 18         knn_fit = preprocess(working_playlist)
#      19         knn.fit(knn_fit)
#      20
#
# TypeError: 'DataFrame' object is not callable
